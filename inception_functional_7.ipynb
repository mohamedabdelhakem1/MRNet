# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
from numpy.random import seed
from sklearn.utils import class_weight

from inception_model_generator_BN import MRNet_inc_model

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #trainning on augmented balanced data with only the skewed class augmented
# 50 epochs

# %%
label_type = 'meniscus'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,0.000001,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
print(total)
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
print(total)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.50.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=100, initial_epoch = 50,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Tensor("sequential_1/mr_net_inception_layer_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Tensor("sequential_1/mr_net_inception_layer_1_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21691809
# =================================================================
# Total params: 21,691,809
# Trainable params: 21,622,945
# Non-trainable params: 68,864
# _________________________________________________________________
# 1017
# 113
# Initializing Data Generator:
# factor :  1.778688524590164
# model:  inception
# data type:  train
# Combination:  meniscus  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1302
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  2.6451612903225805
# model:  inception
# data type:  test
# Combination:  meniscus  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  163
# input size:  (299, 299)
# Epoch 51/100
# 1302/1302 [==============================] - 765s 588ms/step - loss: 0.4381 - tp: 294.3164 - fp: 18.0445 - tn: 311.8833 - fn: 27.2558 - accuracy: 0.9458 - precision: 0.9541 - recall: 0.9318 - auc: 0.9838 - val_loss: 0.6928 - val_tp: 584.0000 - val_fp: 44.0000 - val_tn: 648.9325 - val_fn: 107.0675 - val_accuracy: 0.8913 - val_precision: 0.9299 - val_recall: 0.8461 - val_auc: 0.9645
#
# Epoch 00051: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.51.hdf5
# Epoch 52/100
# 1302/1302 [==============================] - 649s 499ms/step - loss: 0.2247 - tp: 914.3648 - fp: 44.0000 - tn: 1009.0046 - fn: 149.1306 - accuracy: 0.9057 - precision: 0.9521 - recall: 0.8550 - auc: 0.9758 - val_loss: 0.6938 - val_tp: 1233.0000 - val_fp: 44.0000 - val_tn: 1381.0369 - val_fn: 190.9632 - val_accuracy: 0.9176 - val_precision: 0.9655 - val_recall: 0.8661 - val_auc: 0.9831
#
# Epoch 00052: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.52.hdf5
# Epoch 53/100
# 1302/1302 [==============================] - 648s 498ms/step - loss: 0.1028 - tp: 1554.6974 - fp: 44.0000 - tn: 1751.8026 - fn: 231.0000 - accuracy: 0.9224 - precision: 0.9721 - recall: 0.8692 - auc: 0.9856 - val_loss: 0.6925 - val_tp: 1884.0000 - val_fp: 44.0000 - val_tn: 2113.1841 - val_fn: 272.8159 - val_accuracy: 0.9266 - val_precision: 0.9772 - val_recall: 0.8736 - val_auc: 0.9878
#
# Epoch 00053: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.53.hdf5
# Epoch 54/100
# 1302/1302 [==============================] - 652s 501ms/step - loss: 0.0534 - tp: 2211.8296 - fp: 44.0000 - tn: 2478.6704 - fn: 312.0000 - accuracy: 0.9291 - precision: 0.9804 - recall: 0.8757 - auc: 0.9888 - val_loss: 0.6922 - val_tp: 2535.0000 - val_fp: 44.0000 - val_tn: 2846.2332 - val_fn: 353.7669 - val_accuracy: 0.9312 - val_precision: 0.9829 - val_recall: 0.8776 - val_auc: 0.9897
#
# Epoch 00054: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.54.hdf5
# Epoch 55/100
# 1301/1302 [============================>.] - ETA: 0s - loss: 0.0295 - tp: 2860.2197 - fp: 44.0000 - tn: 3213.7803 - fn: 393.0000 - accuracy: 0.9327 - precision: 0.9848 - recall: 0.8788 - auc: 0.9902
# 1302/1302 [==============================] - 650s 499ms/step - loss: 0.0295 - tp: 2860.4700 - fp: 44.0000 - tn: 3214.0300 - fn: 393.0000 - accuracy: 0.9327 - precision: 0.9848 - recall: 0.8788 - auc: 0.9902 - val_loss: 0.6942 - val_tp: 3186.0000 - val_fp: 44.0000 - val_tn: 3577.2700 - val_fn: 436.7301 - val_accuracy: 0.9337 - val_precision: 0.9864 - val_recall: 0.8795 - val_auc: 0.9907
#
# Epoch 00055: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.55.hdf5
# Epoch 56/100
# 1033/1302 [======================>.......] - ETA: 2:07 - loss: 0.0173 - tp: 3440.5935 - fp: 44.0000 - tn: 3883.4065 - fn: 474.0000 - accuracy: 0.9338 - precision: 0.9874 - recall: 0.8787 - auc: 0.9907

# %% [markdown]
# 50 epochs

# %%
label_type = 'meniscus'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
print(total)
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
print(total)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

# model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/axial/weights.10.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=50, initial_epoch = 0,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)

# %% [markdown]
# 20 epochs

# %%
label_type = 'meniscus'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
print(total)
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
print(total)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/axial/weights.10.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=20, initial_epoch = 0,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)

# %% [markdown]
# ## testing on validation dataset

# %%
label_type = 'meniscus'
exam_view = 'axial'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)


pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])
print(total)
neg = total - pos
class_count_valid = {0: neg, 1: pos}

batch_size = 1
valid_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_valid, batch_size=1,model="inception",data_type='valid', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.50.hdf5')
print(model.evaluate_generator(generator=valid_data_gen,steps =total,verbose=1))
metrics = model.predict_generator(generator=valid_data_gen,steps =total,verbose=1);
model.metrics_names
print(metrics)
