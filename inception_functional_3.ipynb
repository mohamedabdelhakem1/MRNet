# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
from numpy.random import seed
from sklearn.utils import class_weight

from inception_model_generator_BN import MRNet_inc_model

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #trainning on augmented balanced data with only the skewed class augmented
# 20 epochs

# %%
label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.50.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=50, initial_epoch = 0,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Tensor("sequential_1/mr_net_inception_layer_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Tensor("sequential_1/mr_net_inception_layer_1_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21691809
# =================================================================
# Total params: 21,691,809
# Trainable params: 21,622,945
# Non-trainable params: 68,864
# _________________________________________________________________
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  inception
# data type:  train
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  inception
# data type:  test
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (299, 299)
# Epoch 1/50
# 1646/1646 [==============================] - 772s 469ms/step - loss: 0.7143 - tp: 164.4423 - fp: 161.6646 - tn: 248.4793 - fn: 248.9137 - accuracy: 0.5120 - precision: 0.5216 - recall: 0.4069 - auc: 0.5201 - val_loss: 0.6926 - val_tp: 325.0000 - val_fp: 324.0000 - val_tn: 543.5444 - val_fn: 543.9556 - val_accuracy: 0.5002 - val_precision: 0.5008 - val_recall: 0.3743 - val_auc: 0.5169
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.01.hdf5
# Epoch 2/50
# 1646/1646 [==============================] - 674s 409ms/step - loss: 0.6817 - tp: 513.6197 - fp: 449.4253 - tn: 871.9229 - fn: 814.5322 - accuracy: 0.5211 - precision: 0.5309 - recall: 0.3843 - auc: 0.5417 - val_loss: 0.6937 - val_tp: 700.0000 - val_fp: 572.0000 - val_tn: 1208.6389 - val_fn: 1081.8611 - val_accuracy: 0.5358 - val_precision: 0.5503 - val_recall: 0.3929 - val_auc: 0.5577
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.02.hdf5
# Epoch 3/50
# 1646/1646 [==============================] - 674s 409ms/step - loss: 0.6374 - tp: 907.3536 - fp: 673.8682 - tn: 1570.0006 - fn: 1324.2776 - accuracy: 0.5525 - precision: 0.5723 - recall: 0.4052 - auc: 0.5817 - val_loss: 0.6936 - val_tp: 1136.0000 - val_fp: 767.0000 - val_tn: 1930.3944 - val_fn: 1555.1056 - val_accuracy: 0.5691 - val_precision: 0.5970 - val_recall: 0.4222 - val_auc: 0.6047
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.03.hdf5
# Epoch 4/50
# 1646/1646 [==============================] - 670s 407ms/step - loss: 0.6153 - tp: 1381.5790 - fp: 857.2928 - tn: 2292.3176 - fn: 1770.3104 - accuracy: 0.5824 - precision: 0.6163 - recall: 0.4375 - auc: 0.6243 - val_loss: 0.6927 - val_tp: 1620.0000 - val_fp: 940.0000 - val_tn: 2669.5000 - val_fn: 1985.0000 - val_accuracy: 0.5946 - val_precision: 0.6328 - val_recall: 0.4494 - val_auc: 0.6408
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.04.hdf5
# Epoch 5/50
# 1646/1646 [==============================] - 674s 409ms/step - loss: 0.5767 - tp: 1879.4526 - fp: 1000.3712 - tn: 3067.5710 - fn: 2180.1052 - accuracy: 0.6082 - precision: 0.6519 - recall: 0.4624 - auc: 0.6612 - val_loss: 0.6928 - val_tp: 2147.0000 - val_fp: 1057.0000 - val_tn: 3462.4556 - val_fn: 2374.0444 - val_accuracy: 0.6205 - val_precision: 0.6701 - val_recall: 0.4749 - val_auc: 0.6795
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.05.hdf5
# Epoch 6/50
# 1646/1646 [==============================] - 675s 410ms/step - loss: 0.5622 - tp: 2428.6130 - fp: 1100.8208 - tn: 3866.5540 - fn: 2557.5122 - accuracy: 0.6321 - precision: 0.6876 - recall: 0.4866 - auc: 0.6959 - val_loss: 0.6935 - val_tp: 2701.0000 - val_fp: 1145.0000 - val_tn: 4285.3999 - val_fn: 2735.1001 - val_accuracy: 0.6429 - val_precision: 0.7023 - val_recall: 0.4969 - val_auc: 0.7108
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.06.hdf5
# Epoch 7/50
# 1646/1646 [==============================] - 674s 410ms/step - loss: 0.5323 - tp: 3006.0662 - fp: 1186.9908 - tn: 4699.3140 - fn: 2887.1289 - accuracy: 0.6538 - precision: 0.7165 - recall: 0.5097 - auc: 0.7257 - val_loss: 0.6934 - val_tp: 3315.0000 - val_fp: 1228.0000 - val_tn: 5114.7056 - val_fn: 3034.7944 - val_accuracy: 0.6642 - val_precision: 0.7297 - val_recall: 0.5221 - val_auc: 0.7397
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.07.hdf5
# Epoch 8/50
#    1/1646 [..............................] - ETA: 10:11 - loss: 0.6617 - tp: 3315.0000 - fp: 1228.0000 - tn: 5164.0000 - fn: 3076.0000 - accuracy: 0.6633 - precision: 0.7297 - recall: 0.5187 - auc: 0.7385
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 1 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 1646/1646 [==============================] - 701s 426ms/step - loss: 0.5192 - tp: 3629.3098 - fp: 1269.4896 - tn: 5535.1572 - fn: 3171.5432 - accuracy: 0.6734 - precision: 0.7406 - recall: 0.5334 - auc: 0.7509 - val_loss: 0.6934 - val_tp: 3951.0000 - val_fp: 1308.0000 - val_tn: 5951.7056 - val_fn: 3307.7944 - val_accuracy: 0.6821 - val_precision: 0.7513 - val_recall: 0.5443 - val_auc: 0.7626
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.08.hdf5
# Epoch 9/50
# 1646/1646 [==============================] - 671s 408ms/step - loss: 0.4963 - tp: 4273.9478 - fp: 1335.8481 - tn: 6384.4404 - fn: 3437.2637 - accuracy: 0.6905 - precision: 0.7617 - recall: 0.5540 - auc: 0.7737 - val_loss: 0.6929 - val_tp: 4597.0000 - val_fp: 1358.0000 - val_tn: 6812.6221 - val_fn: 3576.8777 - val_accuracy: 0.6981 - val_precision: 0.7720 - val_recall: 0.5624 - val_auc: 0.7838
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.09.hdf5
# Epoch 10/50
# 1646/1646 [==============================] - 671s 408ms/step - loss: 0.4805 - tp: 4930.5786 - fp: 1384.7120 - tn: 7253.8091 - fn: 3688.4004 - accuracy: 0.7059 - precision: 0.7806 - recall: 0.5719 - auc: 0.7936 - val_loss: 0.6930 - val_tp: 5273.0000 - val_fp: 1409.0000 - val_tn: 7674.8945 - val_fn: 3813.6055 - val_accuracy: 0.7126 - val_precision: 0.7891 - val_recall: 0.5803 - val_auc: 0.8026
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.10.hdf5
# Epoch 11/50
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.4599 - tp: 5621.3496 - fp: 1428.2985 - tn: 8115.2729 - fn: 3918.0791 - accuracy: 0.7197 - precision: 0.7973 - recall: 0.5891 - auc: 0.8111
# 1646/1646 [==============================] - 673s 409ms/step - loss: 0.4600 - tp: 5621.5669 - fp: 1428.3080 - tn: 8115.5122 - fn: 3918.1130 - accuracy: 0.7197 - precision: 0.7973 - recall: 0.5891 - auc: 0.8111 - val_loss: 0.6933 - val_tp: 5979.0000 - val_fp: 1444.0000 - val_tn: 8554.4443 - val_fn: 4019.0557 - val_accuracy: 0.7268 - val_precision: 0.8055 - val_recall: 0.5980 - val_auc: 0.8197
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.11.hdf5
# Epoch 12/50
# 1646/1646 [==============================] - 677s 412ms/step - loss: 0.4463 - tp: 6342.0591 - fp: 1455.4065 - tn: 8999.2197 - fn: 4112.8154 - accuracy: 0.7336 - precision: 0.8132 - recall: 0.6065 - auc: 0.8274 - val_loss: 0.6930 - val_tp: 6695.0000 - val_fp: 1468.0000 - val_tn: 9444.5498 - val_fn: 4214.9502 - val_accuracy: 0.7396 - val_precision: 0.8202 - val_recall: 0.6137 - val_auc: 0.8345
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.12.hdf5
# Epoch 13/50
# 1646/1646 [==============================] - 674s 409ms/step - loss: 0.4261 - tp: 7075.2856 - fp: 1478.6945 - tn: 9887.8223 - fn: 4293.6982 - accuracy: 0.7460 - precision: 0.8270 - recall: 0.6222 - auc: 0.8418 - val_loss: 0.6932 - val_tp: 7450.0000 - val_fp: 1490.0000 - val_tn: 10334.2607 - val_fn: 4374.2388 - val_accuracy: 0.7520 - val_precision: 0.8333 - val_recall: 0.6301 - val_auc: 0.8485
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.12.hdf5
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.13.hdf5
# Epoch 14/50
# 1646/1646 [==============================] - 673s 409ms/step - loss: 0.4142 - tp: 7821.5747 - fp: 1505.3967 - tn: 10783.5654 - fn: 4450.9580 - accuracy: 0.7574 - precision: 0.8385 - recall: 0.6372 - auc: 0.8545 - val_loss: 0.6932 - val_tp: 8206.1885 - val_fp: 1516.0000 - val_tn: 11227.7773 - val_fn: 4524.5332 - val_accuracy: 0.7629 - val_precision: 0.8441 - val_recall: 0.6446 - val_auc: 0.8602
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.14.hdf5
# Epoch 15/50
# 1646/1646 [==============================] - 675s 410ms/step - loss: 0.4000 - tp: 8583.1533 - fp: 1526.7753 - tn: 11669.9014 - fn: 4607.6572 - accuracy: 0.7675 - precision: 0.8489 - recall: 0.6506 - auc: 0.8656 - val_loss: 0.6931 - val_tp: 8967.9219 - val_fp: 1539.0000 - val_tn: 12109.6338 - val_fn: 4683.9443 - val_accuracy: 0.7721 - val_precision: 0.8535 - val_recall: 0.6569 - val_auc: 0.8707
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.14.hdf5
#
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.15.hdf5
# Epoch 16/50
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.3853 - tp: 9364.9492 - fp: 1550.3519 - tn: 12553.3154 - fn: 4744.3579 - accuracy: 0.7768 - precision: 0.8579 - recall: 0.6637 - auc: 0.8756
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.15.hdf5
# 1646/1646 [==============================] - 674s 410ms/step - loss: 0.3854 - tp: 9365.1826 - fp: 1550.3566 - tn: 12553.5625 - fn: 4744.3730 - accuracy: 0.7768 - precision: 0.8579 - recall: 0.6637 - auc: 0.8756 - val_loss: 0.6931 - val_tp: 9761.0225 - val_fp: 1564.2500 - val_tn: 13000.0107 - val_fn: 4801.2168 - val_accuracy: 0.7815 - val_precision: 0.8619 - val_recall: 0.6703 - val_auc: 0.8802
#
# Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.16.hdf5
# Epoch 17/50
# 1646/1646 [==============================] - 677s 411ms/step - loss: 0.3734 - tp: 10163.5596 - fp: 1579.9861 - tn: 13448.3115 - fn: 4847.6001 - accuracy: 0.7860 - precision: 0.8654 - recall: 0.6770 - auc: 0.8846 - val_loss: 0.6931 - val_tp: 10586.5498 - val_fp: 1600.1111 - val_tn: 13874.4111 - val_fn: 4891.4277 - val_accuracy: 0.7903 - val_precision: 0.8687 - val_recall: 0.6840 - val_auc: 0.8888
#
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.17.hdf5
# Epoch 18/50
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.3627 - tp: 11006.5049 - fp: 1616.3623 - tn: 14309.9385 - fn: 4932.1440 - accuracy: 0.7945 - precision: 0.8719 - recall: 0.6905 - auc: 0.8927
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.17.hdf5
# 1646/1646 [==============================] - 673s 409ms/step - loss: 0.3629 - tp: 11006.7412 - fp: 1616.3657 - tn: 14310.1885 - fn: 4932.1543 - accuracy: 0.7945 - precision: 0.8719 - recall: 0.6905 - auc: 0.8927 - val_loss: 0.6932 - val_tp: 11423.8223 - val_fp: 1643.9000 - val_tn: 14742.4385 - val_fn: 4968.3389 - val_accuracy: 0.7983 - val_precision: 0.8742 - val_recall: 0.6969 - val_auc: 0.8964
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.18.hdf5
# Epoch 19/50
# 1646/1646 [==============================] - 675s 410ms/step - loss: 0.3510 - tp: 11855.8740 - fp: 1678.0559 - tn: 15166.7119 - fn: 4990.7832 - accuracy: 0.8020 - precision: 0.8760 - recall: 0.7037 - auc: 0.9000 - val_loss: 0.6932 - val_tp: 12285.4551 - val_fp: 1718.4556 - val_tn: 15584.7334 - val_fn: 5015.8555 - val_accuracy: 0.8054 - val_precision: 0.8773 - val_recall: 0.7101 - val_auc: 0.9033
#
# Epoch 00019: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.19.hdf5
# Epoch 20/50
# 1646/1646 [==============================] - 675s 410ms/step - loss: 0.3362 - tp: 12733.8613 - fp: 1753.4241 - tn: 16000.4834 - fn: 5029.6274 - accuracy: 0.8090 - precision: 0.8789 - recall: 0.7168 - auc: 0.9065 - val_loss: 0.6932 - val_tp: 13173.4668 - val_fp: 1796.5333 - val_tn: 16420.1172 - val_fn: 5040.3833 - val_accuracy: 0.8123 - val_precision: 0.8800 - val_recall: 0.7233 - val_auc: 0.9096
#
# Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.20.hdf5
# Epoch 21/50
# 1646/1646 [==============================] - 677s 411ms/step - loss: 0.3295 - tp: 13616.9043 - fp: 1840.1774 - tn: 16833.3125 - fn: 5053.0298 - accuracy: 0.8154 - precision: 0.8809 - recall: 0.7293 - auc: 0.9124 - val_loss: 0.6930 - val_tp: 14062.2607 - val_fp: 1886.2389 - val_tn: 17239.1328 - val_fn: 5068.8667 - val_accuracy: 0.8182 - val_precision: 0.8817 - val_recall: 0.7350 - val_auc: 0.9151
#
# Epoch 00021: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.21.hdf5
# Epoch 22/50
# 1646/1646 [==============================] - 676s 411ms/step - loss: 0.3200 - tp: 14493.8770 - fp: 1931.8949 - tn: 17665.3633 - fn: 5078.2510 - accuracy: 0.8210 - precision: 0.8824 - recall: 0.7405 - auc: 0.9176 - val_loss: 0.6931 - val_tp: 14953.3389 - val_fp: 1981.1611 - val_tn: 18062.0000 - val_fn: 5086.0000 - val_accuracy: 0.8237 - val_precision: 0.8830 - val_recall: 0.7462 - val_auc: 0.9201
#
# Epoch 00022: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.22.hdf5
# Epoch 23/50
# 1646/1646 [==============================] - 677s 411ms/step - loss: 0.3100 - tp: 15401.4336 - fp: 2026.4106 - tn: 18476.9316 - fn: 5090.5703 - accuracy: 0.8264 - precision: 0.8837 - recall: 0.7516 - auc: 0.9225 - val_loss: 0.6932 - val_tp: 15862.8164 - val_fp: 2071.6833 - val_tn: 18881.0000 - val_fn: 5093.0000 - val_accuracy: 0.8290 - val_precision: 0.8845 - val_recall: 0.7570 - val_auc: 0.9248
#
# Epoch 00023: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.23.hdf5
# Epoch 24/50
# 1646/1646 [==============================] - 673s 409ms/step - loss: 0.2991 - tp: 16325.9932 - fp: 2119.6477 - tn: 19276.3066 - fn: 5099.4297 - accuracy: 0.8314 - precision: 0.8851 - recall: 0.7620 - auc: 0.9269 - val_loss: 0.6930 - val_tp: 16760.5117 - val_fp: 2170.9888 - val_tn: 19699.0000 - val_fn: 5104.0000 - val_accuracy: 0.8337 - val_precision: 0.8853 - val_recall: 0.7666 - val_auc: 0.9289
#
# Epoch 00024: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.24.hdf5
# Epoch 25/50
# 1646/1646 [==============================] - 674s 409ms/step - loss: 0.2896 - tp: 17209.7305 - fp: 2214.7832 - tn: 20114.7168 - fn: 5108.1172 - accuracy: 0.8360 - precision: 0.8860 - recall: 0.7711 - auc: 0.9309 - val_loss: 0.6933 - val_tp: 17668.8164 - val_fp: 2261.6833 - val_tn: 20519.0000 - val_fn: 5111.0000 - val_accuracy: 0.8382 - val_precision: 0.8865 - val_recall: 0.7756 - val_auc: 0.9328
#
# Epoch 00025: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.25.hdf5
# Epoch 26/50
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.2781 - tp: 18111.3027 - fp: 2308.0876 - tn: 20939.8906 - fn: 5113.5830 - accuracy: 0.8403 - precision: 0.8870 - recall: 0.7798 - auc: 0.9346
# Epoch 00025: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.25.hdf5
# 1646/1646 [==============================] - 674s 409ms/step - loss: 0.2780 - tp: 18111.5547 - fp: 2308.0886 - tn: 20940.1309 - fn: 5113.5869 - accuracy: 0.8403 - precision: 0.8870 - recall: 0.7798 - auc: 0.9346 - val_loss: 0.6929 - val_tp: 18570.2832 - val_fp: 2358.2166 - val_tn: 21338.0000 - val_fn: 5120.0000 - val_accuracy: 0.8422 - val_precision: 0.8873 - val_recall: 0.7839 - val_auc: 0.9363
#
# Epoch 00026: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/abnormal/sagittal/weights.26.hdf5
# Epoch 27/50
# 1019/1646 [=================>............] - ETA: 4:06 - loss: 0.2748 - tp: 18882.8223 - fp: 2400.7153 - tn: 21581.0996 - fn: 5121.2993 - accuracy: 0.8432 - precision: 0.8872 - recall: 0.7866 - auc: 0.9372

# %%
label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/axial/weights.10.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=20, initial_epoch = 0,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21691809
# =================================================================
# Total params: 21,691,809
# Trainable params: 21,657,377
# Non-trainable params: 34,432
# _________________________________________________________________
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  inception
# data type:  train
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  inception
# data type:  test
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (299, 299)
# Epoch 1/20
# 1646/1646 [==============================] - 1384s 841ms/step - loss: 0.6833 - tp: 344.4131 - fp: 252.1367 - tn: 163.5085 - fn: 63.4417 - accuracy: 0.5709 - precision: 0.5408 - recall: 0.8701 - auc: 0.6438 - val_loss: 0.6885 - val_tp: 725.1000 - val_fp: 438.4000 - val_tn: 429.0000 - val_fn: 144.0000 - val_accuracy: 0.6648 - val_precision: 0.6235 - val_recall: 0.8342 - val_auc: 0.7197
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.01.hdf5
# Epoch 2/20
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.2879 - tp: 1139.5161 - fp: 531.9714 - tn: 791.9417 - fn: 185.5708 - accuracy: 0.7229 - precision: 0.6768 - recall: 0.8581 - auc: 0.7928
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.01.hdf5
# 1646/1646 [==============================] - 1151s 700ms/step - loss: 0.2881 - tp: 1139.7455 - fp: 531.9885 - tn: 792.1750 - fn: 185.5911 - accuracy: 0.7229 - precision: 0.6769 - recall: 0.8581 - auc: 0.7928 - val_loss: 0.6898 - val_tp: 1562.3055 - val_fp: 605.1945 - val_tn: 1176.0000 - val_fn: 219.0000 - val_accuracy: 0.7687 - val_precision: 0.7209 - val_recall: 0.8770 - val_auc: 0.8468
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.02.hdf5
# Epoch 3/20
# 1646/1646 [==============================] - 1152s 700ms/step - loss: 0.1331 - tp: 2012.4896 - fp: 661.7922 - tn: 1575.5796 - fn: 225.6385 - accuracy: 0.7996 - precision: 0.7507 - recall: 0.8981 - auc: 0.8813 - val_loss: 0.6900 - val_tp: 2467.3723 - val_fp: 711.1278 - val_tn: 1981.0000 - val_fn: 229.0000 - val_accuracy: 0.8256 - val_precision: 0.7763 - val_recall: 0.9151 - val_auc: 0.9082
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.03.hdf5
# Epoch 4/20
# 1646/1646 [==============================] - 1150s 698ms/step - loss: 0.0658 - tp: 2918.8367 - fp: 759.1877 - tn: 2393.6750 - fn: 229.8007 - accuracy: 0.8422 - precision: 0.7927 - recall: 0.9266 - auc: 0.9251 - val_loss: 0.6968 - val_tp: 3377.3057 - val_fp: 804.1945 - val_tn: 2802.0000 - val_fn: 231.0000 - val_accuracy: 0.8565 - val_precision: 0.8077 - val_recall: 0.9360 - val_auc: 0.9384
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.04.hdf5
# Epoch 5/20
# 1646/1646 [==============================] - 1151s 699ms/step - loss: 0.0336 - tp: 3834.1743 - fp: 850.5845 - tn: 3211.7412 - fn: 231.0000 - accuracy: 0.8665 - precision: 0.8180 - recall: 0.9430 - auc: 0.9475 - val_loss: 0.6894 - val_tp: 4292.1611 - val_fp: 893.3389 - val_tn: 3624.0000 - val_fn: 231.0000 - val_accuracy: 0.8756 - val_precision: 0.8278 - val_recall: 0.9489 - val_auc: 0.9550
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.05.hdf5
# Epoch 6/20
# 1646/1646 [==============================] - 1156s 703ms/step - loss: 0.0178 - tp: 4741.4800 - fp: 941.0000 - tn: 4040.0200 - fn: 231.0000 - accuracy: 0.8820 - precision: 0.8341 - recall: 0.9534 - auc: 0.9604 - val_loss: 0.6890 - val_tp: 5203.3613 - val_fp: 985.1389 - val_tn: 4447.0000 - val_fn: 231.0000 - val_accuracy: 0.8881 - val_precision: 0.8408 - val_recall: 0.9575 - val_auc: 0.9650
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.06.hdf5
# Epoch 7/20
# 1646/1646 [==============================] - 1159s 704ms/step - loss: 0.0098 - tp: 5663.7417 - fp: 1031.0000 - tn: 4853.7583 - fn: 231.0000 - accuracy: 0.8927 - precision: 0.8458 - recall: 0.9608 - auc: 0.9684 - val_loss: 0.6976 - val_tp: 6114.9946 - val_fp: 1076.5056 - val_tn: 5270.0000 - val_fn: 231.0000 - val_accuracy: 0.8970 - val_precision: 0.8503 - val_recall: 0.9636 - val_auc: 0.9714
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.07.hdf5
# Epoch 8/20
# 1646/1646 [==============================] - 1146s 696ms/step - loss: 0.0061 - tp: 6568.9409 - fp: 1121.0000 - tn: 5684.5591 - fn: 231.0000 - accuracy: 0.9005 - precision: 0.8541 - recall: 0.9660 - auc: 0.9737 - val_loss: 0.6886 - val_tp: 7025.2778 - val_fp: 1169.2222 - val_tn: 6093.0000 - val_fn: 231.0000 - val_accuracy: 0.9036 - val_precision: 0.8573 - val_recall: 0.9682 - val_auc: 0.9758
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.08.hdf5
# Epoch 9/20
# 1646/1646 [==============================] - 1155s 702ms/step - loss: 0.0039 - tp: 7483.2046 - fp: 1211.0000 - tn: 6506.2954 - fn: 231.0000 - accuracy: 0.9065 - precision: 0.8606 - recall: 0.9700 - auc: 0.9774 - val_loss: 0.6885 - val_tp: 7942.4165 - val_fp: 1255.0834 - val_tn: 6916.0000 - val_fn: 231.0000 - val_accuracy: 0.9091 - val_precision: 0.8636 - val_recall: 0.9717 - val_auc: 0.9789
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.09.hdf5
# Epoch 10/20
# 1646/1646 [==============================] - 1159s 704ms/step - loss: 0.0025 - tp: 8394.3008 - fp: 1301.0000 - tn: 7331.1992 - fn: 231.0000 - accuracy: 0.9112 - precision: 0.8657 - recall: 0.9732 - auc: 0.9802 - val_loss: 0.6980 - val_tp: 8854.6836 - val_fp: 1345.8167 - val_tn: 7739.0000 - val_fn: 231.0000 - val_accuracy: 0.9132 - val_precision: 0.8681 - val_recall: 0.9746 - val_auc: 0.9813
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.10.hdf5
# Epoch 11/20
# 1646/1646 [==============================] - 1149s 698ms/step - loss: 0.0018 - tp: 9309.6016 - fp: 1391.0000 - tn: 8151.8984 - fn: 231.0000 - accuracy: 0.9150 - precision: 0.8699 - recall: 0.9758 - auc: 0.9822 - val_loss: 0.6980 - val_tp: 9766.1943 - val_fp: 1437.3055 - val_tn: 8562.0000 - val_fn: 231.0000 - val_accuracy: 0.9166 - val_precision: 0.8717 - val_recall: 0.9769 - val_auc: 0.9831
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.11.hdf5
# Epoch 12/20
# 1646/1646 [==============================] - 1156s 702ms/step - loss: 0.0013 - tp: 10220.8525 - fp: 1481.0000 - tn: 8976.6475 - fn: 231.0000 - accuracy: 0.9181 - precision: 0.8734 - recall: 0.9779 - auc: 0.9838 - val_loss: 0.6882 - val_tp: 10680.3662 - val_fp: 1526.1333 - val_tn: 9385.0000 - val_fn: 231.0000 - val_accuracy: 0.9195 - val_precision: 0.8750 - val_recall: 0.9788 - val_auc: 0.9845
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.12.hdf5
# Epoch 13/20
# 1646/1646 [==============================] - 1154s 701ms/step - loss: 9.3148e-04 - tp: 11128.6123 - fp: 1571.0000 - tn: 9804.8721 - fn: 231.0000 - accuracy: 0.9207 - precision: 0.8763 - recall: 0.9797 - auc: 0.9851 - val_loss: 0.6882 - val_tp: 11592.9609 - val_fp: 1616.5389 - val_tn: 10208.0000 - val_fn: 231.0000 - val_accuracy: 0.9219 - val_precision: 0.8776 - val_recall: 0.9805 - val_auc: 0.9856
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.13.hdf5
# Epoch 14/20
# 1645/1646 [============================>.] - ETA: 0s - loss: 6.8919e-04 - tp: 12037.5879 - fp: 1661.0000 - tn: 10631.3682 - fn: 231.0000 - accuracy: 0.9229 - precision: 0.8787 - recall: 0.9812 - auc: 0.9861
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.13.hdf5
# 1646/1646 [==============================] - 1156s 702ms/step - loss: 6.8878e-04 - tp: 12037.8447 - fp: 1661.0000 - tn: 10631.6113 - fn: 231.0000 - accuracy: 0.9229 - precision: 0.8787 - recall: 0.9812 - auc: 0.9861 - val_loss: 0.6982 - val_tp: 12504.8281 - val_fp: 1707.6722 - val_tn: 11031.0000 - val_fn: 231.0000 - val_accuracy: 0.9239 - val_precision: 0.8799 - val_recall: 0.9819 - val_auc: 0.9865
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.14.hdf5
# Epoch 15/20
# 1646/1646 [==============================] - 1154s 701ms/step - loss: 5.5468e-04 - tp: 12962.9111 - fp: 1751.0000 - tn: 11442.5186 - fn: 231.0000 - accuracy: 0.9249 - precision: 0.8810 - recall: 0.9825 - auc: 0.9869 - val_loss: 0.6983 - val_tp: 13417.9727 - val_fp: 1797.5278 - val_tn: 11854.0000 - val_fn: 231.0000 - val_accuracy: 0.9257 - val_precision: 0.8819 - val_recall: 0.9831 - val_auc: 0.9873
#
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.15.hdf5
# Epoch 16/20
# 1646/1646 [==============================] - 1157s 703ms/step - loss: 4.6863e-04 - tp: 13883.8564 - fp: 1841.0000 - tn: 12257.5723 - fn: 231.0000 - accuracy: 0.9265 - precision: 0.8829 - recall: 0.9836 - auc: 0.9876 - val_loss: 0.6879 - val_tp: 14328.3887 - val_fp: 1890.1111 - val_tn: 12677.0000 - val_fn: 231.0000 - val_accuracy: 0.9272 - val_precision: 0.8835 - val_recall: 0.9841 - val_auc: 0.9879
#
# Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.16.hdf5
# Epoch 17/20
# 1645/1646 [============================>.] - ETA: 0s - loss: 3.6591e-04 - tp: 14797.1328 - fp: 1931.0000 - tn: 13079.7832 - fn: 231.0000 - accuracy: 0.9280 - precision: 0.8845 - recall: 0.9846 - auc: 0.9882
# Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.16.hdf5
# 1646/1646 [==============================] - 1148s 697ms/step - loss: 3.6578e-04 - tp: 14797.3779 - fp: 1931.0000 - tn: 13080.0391 - fn: 231.0000 - accuracy: 0.9280 - precision: 0.8845 - recall: 0.9846 - auc: 0.9882 - val_loss: 0.6983 - val_tp: 15241.9941 - val_fp: 1979.5056 - val_tn: 13500.0000 - val_fn: 231.0000 - val_accuracy: 0.9286 - val_precision: 0.8851 - val_recall: 0.9851 - val_auc: 0.9885
#
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.17.hdf5
# Epoch 18/20
# 1645/1646 [============================>.] - ETA: 0s - loss: 2.9144e-04 - tp: 15699.4160 - fp: 2021.0000 - tn: 13913.4639 - fn: 231.0000 - accuracy: 0.9293 - precision: 0.8859 - recall: 0.9855 - auc: 0.9887
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.17.hdf5
# 1646/1646 [==============================] - 1158s 703ms/step - loss: 2.9129e-04 - tp: 15699.6670 - fp: 2021.0000 - tn: 13913.7129 - fn: 231.0000 - accuracy: 0.9293 - precision: 0.8859 - recall: 0.9855 - auc: 0.9887 - val_loss: 0.6984 - val_tp: 16159.4668 - val_fp: 2065.0334 - val_tn: 14323.0000 - val_fn: 231.0000 - val_accuracy: 0.9300 - val_precision: 0.8867 - val_recall: 0.9859 - val_auc: 0.9890
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.18.hdf5
# Epoch 19/20
# 1646/1646 [==============================] - 1159s 704ms/step - loss: 2.8116e-04 - tp: 16611.1367 - fp: 2111.0000 - tn: 14738.2676 - fn: 231.0000 - accuracy: 0.9305 - precision: 0.8872 - recall: 0.9863 - auc: 0.9892 - val_loss: 0.6880 - val_tp: 17068.1660 - val_fp: 2159.3333 - val_tn: 15146.0000 - val_fn: 231.0000 - val_accuracy: 0.9309 - val_precision: 0.8877 - val_recall: 0.9866 - val_auc: 0.9894
#
# Epoch 00019: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.19.hdf5
# Epoch 20/20
# 1646/1646 [==============================] - 1160s 705ms/step - loss: 2.3247e-04 - tp: 17529.7129 - fp: 2201.0000 - tn: 15555.6748 - fn: 231.0000 - accuracy: 0.9315 - precision: 0.8884 - recall: 0.9870 - auc: 0.9896 - val_loss: 0.6878 - val_tp: 17981.2949 - val_fp: 2249.2056 - val_tn: 15969.0000 - val_fn: 231.0000 - val_accuracy: 0.9319 - val_precision: 0.8888 - val_recall: 0.9873 - val_auc: 0.9898
#
# Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.20.hdf5

# %% [markdown]
# ## training on augmneted data

# %%
label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_inc_model(2,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=1)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=1)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/sagittal/weights.20.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=30, initial_epoch = 20,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)

# %%
label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/"+label_type+"/"+exam_view+"/weights.20.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])
neg = total - pos
class_count_valid = {0: neg, 1: pos}
batch_size = 1
print(model.metrics_names)
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , batch_size=1,model="inception",data_type='valid', shuffle=False,label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
model.evaluate_generator(valid_data_gen, total, verbose=1)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_5 (MR (None, 1)                 21691809
# =================================================================
# Total params: 21,691,809
# Trainable params: 21,657,377
# Non-trainable params: 34,432
# _________________________________________________________________
# ['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc']
# Initializing Data Generator:
# factor :  3.8
# model:  inception
# data type:  valid
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  190
# input size:  (299, 299)
# 120/120 [==============================] - 18s 152ms/step
# [0.6878566741943359,
#  47.900001525878906,
#  12.600000381469727,
#  0.0,
#  0.0,
#  0.7565382719039917,
#  0.7565382719039917,
#  0.9916666746139526,
#  0.4958333373069763]
