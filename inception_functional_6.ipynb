# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/MRNet/'
# /content

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
from numpy.random import seed
from sklearn.utils import class_weight

from inception_model_generator_BN import MRNet_inc_model

import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d474d8c06ebc> in <module>()
#       5 import keras
#       6 import scipy
# ----> 7 from partition import partition
#       8 from data_generator import MRNet_data_generator
#       9 from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
#
# ModuleNotFoundError: No module named 'partition'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# #trainning on augmented balanced data with only the skewed class augmented
# 50 epochs

# %%
label_type = 'ACL'
exam_view = 'sagittal'
model, cbs = MRNet_inc_model(2,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
print(total)
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
print(total)
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=1)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=1)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.50.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=50, initial_epoch = 0,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)

# %% [markdown]
# 20 epochs

# %%
label_type = 'ACL'
exam_view = 'sagittal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
print(total)
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
print(total)
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

# model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/ACL/sagittal/weights.14.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=50, initial_epoch = 0,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Tensor("sequential_1/mr_net_inception_layer_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Tensor("sequential_1/mr_net_inception_layer_1_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21691809
# =================================================================
# Total params: 21,691,809
# Trainable params: 21,622,945
# Non-trainable params: 68,864
# _________________________________________________________________
# 1017
# 113
# Initializing Data Generator:
# factor :  4.16243654822335
# model:  inception
# data type:  train
# Combination:  ACL  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1639
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  9.272727272727273
# model:  inception
# data type:  test
# Combination:  ACL  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  204
# input size:  (299, 299)
# Epoch 1/50
# 1639/1639 [==============================] - 779s 475ms/step - loss: 0.7519 - tp: 37.4588 - fp: 29.9951 - tn: 377.8505 - fn: 374.6956 - accuracy: 0.4997 - precision: 0.5525 - recall: 0.0842 - auc: 0.5634 - val_loss: 0.6924 - val_tp: 83.0000 - val_fp: 61.0000 - val_tn: 808.1323 - val_fn: 789.3677 - val_accuracy: 0.5117 - val_precision: 0.5764 - val_recall: 0.0952 - val_auc: 0.5629
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.01.hdf5
# Epoch 2/50
# 1638/1639 [============================>.] - ETA: 0s - loss: 0.6852 - tp: 159.1111 - fp: 95.8309 - tn: 1233.1978 - fn: 1174.3602 - accuracy: 0.5217 - precision: 0.6197 - recall: 0.1163 - auc: 0.5817
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.01.hdf5
# 1639/1639 [==============================] - 698s 426ms/step - loss: 0.6850 - tp: 159.1696 - fp: 95.8578 - tn: 1233.4229 - fn: 1174.5497 - accuracy: 0.5217 - precision: 0.6197 - recall: 0.1163 - auc: 0.5817 - val_loss: 0.6936 - val_tp: 255.0000 - val_fp: 140.0000 - val_tn: 1650.8235 - val_fn: 1538.6765 - val_accuracy: 0.5317 - val_precision: 0.6456 - val_recall: 0.1422 - val_auc: 0.5986
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.02.hdf5
# Epoch 3/50
# 1639/1639 [==============================] - 700s 427ms/step - loss: 0.6438 - tp: 391.7431 - fp: 188.8249 - tn: 2072.1978 - fn: 1853.2343 - accuracy: 0.5460 - precision: 0.6719 - recall: 0.1723 - auc: 0.6143 - val_loss: 0.6936 - val_tp: 550.0000 - val_fp: 242.0000 - val_tn: 2471.4854 - val_fn: 2164.0146 - val_accuracy: 0.5567 - val_precision: 0.6944 - val_recall: 0.2027 - val_auc: 0.6282
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.02.hdf5
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.03.hdf5
# Epoch 4/50
# 1639/1639 [==============================] - 694s 423ms/step - loss: 0.6094 - tp: 744.2099 - fp: 288.2709 - tn: 2877.5278 - fn: 2438.9915 - accuracy: 0.5698 - precision: 0.7189 - recall: 0.2323 - auc: 0.6436 - val_loss: 0.6936 - val_tp: 949.0000 - val_fp: 348.0000 - val_tn: 3288.6519 - val_fn: 2684.8481 - val_accuracy: 0.5829 - val_precision: 0.7317 - val_recall: 0.2612 - val_auc: 0.6576
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.03.hdf5
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.04.hdf5
# Epoch 5/50
# 1638/1639 [============================>.] - ETA: 0s - loss: 0.5831 - tp: 1187.1691 - fp: 407.9725 - tn: 3687.9756 - fn: 2908.3828 - accuracy: 0.5947 - precision: 0.7436 - recall: 0.2888 - auc: 0.6707
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.04.hdf5
# 1639/1639 [==============================] - 703s 429ms/step - loss: 0.5830 - tp: 1187.3221 - fp: 408.0122 - tn: 3688.1873 - fn: 2908.4783 - accuracy: 0.5947 - precision: 0.7436 - recall: 0.2889 - auc: 0.6707 - val_loss: 0.6936 - val_tp: 1438.0000 - val_fp: 473.0000 - val_tn: 4083.3774 - val_fn: 3119.1226 - val_accuracy: 0.6059 - val_precision: 0.7525 - val_recall: 0.3156 - val_auc: 0.6826
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.05.hdf5
# Epoch 6/50
# 1639/1639 [==============================] - 699s 426ms/step - loss: 0.5416 - tp: 1729.9078 - fp: 525.7279 - tn: 4509.0347 - fn: 3270.3296 - accuracy: 0.6213 - precision: 0.7661 - recall: 0.3451 - auc: 0.6964 - val_loss: 0.6929 - val_tp: 2050.0000 - val_fp: 577.0000 - val_tn: 4901.5835 - val_fn: 3427.9167 - val_accuracy: 0.6345 - val_precision: 0.7804 - val_recall: 0.3742 - val_auc: 0.7109
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.06.hdf5
# Epoch 7/50
# 1639/1639 [==============================] - 701s 428ms/step - loss: 0.5274 - tp: 2370.4741 - fp: 640.6534 - tn: 5303.8076 - fn: 3563.0647 - accuracy: 0.6458 - precision: 0.7869 - recall: 0.3989 - auc: 0.7221 - val_loss: 0.6934 - val_tp: 2692.0000 - val_fp: 702.0000 - val_tn: 5704.7207 - val_fn: 3700.7793 - val_accuracy: 0.6560 - val_precision: 0.7932 - val_recall: 0.4211 - val_auc: 0.7327
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.07.hdf5
# Epoch 8/50
# 1638/1639 [============================>.] - ETA: 0s - loss: 0.5088 - tp: 3036.5361 - fp: 764.5757 - tn: 6094.0142 - fn: 3825.3743 - accuracy: 0.6653 - precision: 0.7987 - recall: 0.4421 - auc: 0.7425
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.07.hdf5
# 1639/1639 [==============================] - 704s 430ms/step - loss: 0.5087 - tp: 3036.7412 - fp: 764.6113 - tn: 6094.2319 - fn: 3825.4155 - accuracy: 0.6653 - precision: 0.7987 - recall: 0.4421 - auc: 0.7425 - val_loss: 0.6928 - val_tp: 3373.0000 - val_fp: 823.0000 - val_tn: 6501.7158 - val_fn: 3944.7844 - val_accuracy: 0.6744 - val_precision: 0.8039 - val_recall: 0.4609 - val_auc: 0.7524
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.08.hdf5
# Epoch 9/50
# 1639/1639 [==============================] - 699s 427ms/step - loss: 0.4903 - tp: 3732.7175 - fp: 889.3990 - tn: 6894.0117 - fn: 4047.8718 - accuracy: 0.6826 - precision: 0.8075 - recall: 0.4794 - auc: 0.7611 - val_loss: 0.6936 - val_tp: 4086.0000 - val_fp: 943.0000 - val_tn: 7304.2646 - val_fn: 4152.2354 - val_accuracy: 0.6909 - val_precision: 0.8125 - val_recall: 0.4960 - val_auc: 0.7703
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.09.hdf5
# Epoch 10/50
# 1638/1639 [============================>.] - ETA: 0s - loss: 0.4662 - tp: 4453.9458 - fp: 992.1667 - tn: 7719.0015 - fn: 4241.3862 - accuracy: 0.6992 - precision: 0.8177 - recall: 0.5119 - auc: 0.7789
# 1639/1639 [==============================] - 699s 427ms/step - loss: 0.4663 - tp: 4454.1753 - fp: 992.1922 - tn: 7719.2241 - fn: 4241.4087 - accuracy: 0.6992 - precision: 0.8177 - recall: 0.5120 - auc: 0.7789 - val_loss: 0.6929 - val_tp: 4830.0000 - val_fp: 1034.0000 - val_tn: 8137.0098 - val_fn: 4327.4902 - val_accuracy: 0.7075 - val_precision: 0.8237 - val_recall: 0.5274 - val_auc: 0.7878
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.10.hdf5
# Epoch 11/50
# 1639/1639 [==============================] - 698s 426ms/step - loss: 0.4479 - tp: 5200.4580 - fp: 1073.3630 - tn: 8567.8984 - fn: 4408.2808 - accuracy: 0.7151 - precision: 0.8288 - recall: 0.5410 - auc: 0.7961 - val_loss: 0.6928 - val_tp: 5594.0000 - val_fp: 1119.0000 - val_tn: 8968.7158 - val_fn: 4489.7842 - val_accuracy: 0.7219 - val_precision: 0.8333 - val_recall: 0.5548 - val_auc: 0.8039
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.11.hdf5
# Epoch 12/50
# 1639/1639 [==============================] - 702s 428ms/step - loss: 0.4369 - tp: 5973.9844 - fp: 1163.6913 - tn: 9398.2754 - fn: 4557.0488 - accuracy: 0.7287 - precision: 0.8369 - recall: 0.5671 - auc: 0.8110 - val_loss: 0.6928 - val_tp: 6371.0000 - val_fp: 1207.0000 - val_tn: 9808.9951 - val_fn: 4627.5049 - val_accuracy: 0.7350 - val_precision: 0.8407 - val_recall: 0.5793 - val_auc: 0.8177
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.12.hdf5
# Epoch 13/50
# 1639/1639 [==============================] - 699s 426ms/step - loss: 0.4228 - tp: 6766.8315 - fp: 1241.2959 - tn: 10219.9688 - fn: 4707.9038 - accuracy: 0.7405 - precision: 0.8449 - recall: 0.5896 - auc: 0.8242 - val_loss: 0.6928 - val_tp: 7138.0000 - val_fp: 1280.0000 - val_tn: 10652.5635 - val_fn: 4786.9360 - val_accuracy: 0.7457 - val_precision: 0.8479 - val_recall: 0.5986 - val_auc: 0.8302
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.13.hdf5
# Epoch 14/50
# 1639/1639 [==============================] - 695s 424ms/step - loss: 0.4091 - tp: 7530.8491 - fp: 1306.5192 - tn: 11086.5127 - fn: 4855.1069 - accuracy: 0.7513 - precision: 0.8521 - recall: 0.6079 - auc: 0.8359 - val_loss: 0.6936 - val_tp: 7921.0000 - val_fp: 1332.0000 - val_tn: 11525.0830 - val_fn: 4922.4165 - val_accuracy: 0.7566 - val_precision: 0.8560 - val_recall: 0.6167 - val_auc: 0.8416
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.14.hdf5
# Epoch 15/50
# 1639/1639 [==============================] - 698s 426ms/step - loss: 0.3895 - tp: 8314.4854 - fp: 1352.9200 - tn: 11972.8018 - fn: 4981.7720 - accuracy: 0.7620 - precision: 0.8600 - recall: 0.6252 - auc: 0.8471 - val_loss: 0.6928 - val_tp: 8724.0000 - val_fp: 1370.0000 - val_tn: 12409.2891 - val_fn: 5040.2109 - val_accuracy: 0.7673 - val_precision: 0.8643 - val_recall: 0.6338 - val_auc: 0.8525
#
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.15.hdf5
# Epoch 16/50
# 1638/1639 [============================>.] - ETA: 0s - loss: 0.3858 - tp: 9119.6201 - fp: 1393.1141 - tn: 12844.9941 - fn: 5106.7422 - accuracy: 0.7716 - precision: 0.8674 - recall: 0.6409 - auc: 0.8572
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.15.hdf5
# 1639/1639 [==============================] - 700s 427ms/step - loss: 0.3858 - tp: 9119.8594 - fp: 1393.1294 - tn: 12845.2305 - fn: 5106.7515 - accuracy: 0.7716 - precision: 0.8674 - recall: 0.6410 - auc: 0.8572 - val_loss: 0.6926 - val_tp: 9512.0000 - val_fp: 1418.0000 - val_tn: 13281.3281 - val_fn: 5175.1714 - val_accuracy: 0.7756 - val_precision: 0.8703 - val_recall: 0.6476 - val_auc: 0.8615
#
# Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.16.hdf5
# Epoch 17/50
# 1639/1639 [==============================] - 700s 427ms/step - loss: 0.3858 - tp: 9119.8594 - fp: 1393.1294 - tn: 12845.2305 - fn: 5106.7515 - accuracy: 0.7716 - precision: 0.8674 - recall: 0.6410 - auc: 0.8572 - val_loss: 0.6926 - val_tp: 9512.0000 - val_fp: 1418.0000 - val_tn: 13281.3281 - val_fn: 5175.1714 - val_accuracy: 0.7756 - val_precision: 0.8703 - val_recall: 0.6476 - val_auc: 0.8615
# 1639/1639 [==============================] - 702s 428ms/step - loss: 0.3712 - tp: 9908.3115 - fp: 1443.9847 - tn: 13721.8096 - fn: 5233.8687 - accuracy: 0.7796 - precision: 0.8728 - recall: 0.6543 - auc: 0.8658 - val_loss: 0.6936 - val_tp: 10307.0000 - val_fp: 1462.0000 - val_tn: 14164.0781 - val_fn: 5296.4214 - val_accuracy: 0.7836 - val_precision: 0.8758 - val_recall: 0.6606 - val_auc: 0.8699
#
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.17.hdf5
# Epoch 18/50
# 1639/1639 [==============================] - 702s 428ms/step - loss: 0.3602 - tp: 10702.2881 - fp: 1480.9066 - tn: 14608.7471 - fn: 5358.9990 - accuracy: 0.7872 - precision: 0.8784 - recall: 0.6663 - auc: 0.8738 - val_loss: 0.6936 - val_tp: 11110.0000 - val_fp: 1497.0000 - val_tn: 15051.0732 - val_fn: 5414.4263 - val_accuracy: 0.7910 - val_precision: 0.8813 - val_recall: 0.6723 - val_auc: 0.8777
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.18.hdf5
# Epoch 19/50
# 1639/1639 [==============================] - 701s 427ms/step - loss: 0.3525 - tp: 11512.5811 - fp: 1510.2159 - tn: 15495.6367 - fn: 5475.4917 - accuracy: 0.7945 - precision: 0.8840 - recall: 0.6776 - auc: 0.8813 - val_loss: 0.6936 - val_tp: 11910.0000 - val_fp: 1525.0000 - val_tn: 15938.3975 - val_fn: 5542.1030 - val_accuracy: 0.7976 - val_precision: 0.8865 - val_recall: 0.6824 - val_auc: 0.8847
#
# Epoch 00019: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.19.hdf5
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.18.hdf5
# Epoch 20/50
# 1639/1639 [==============================] - 700s 427ms/step - loss: 0.3409 - tp: 12313.1104 - fp: 1536.0464 - tn: 16391.7715 - fn: 5595.9941 - accuracy: 0.8010 - precision: 0.8891 - recall: 0.6875 - auc: 0.8880 - val_loss: 0.6937 - val_tp: 12715.0000 - val_fp: 1550.0000 - val_tn: 16839.7695 - val_fn: 5653.7305 - val_accuracy: 0.8040 - val_precision: 0.8913 - val_recall: 0.6922 - val_auc: 0.8912
#
# Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.20.hdf5
# Epoch 21/50
# 1638/1639 [============================>.] - ETA: 0s - loss: 0.3259 - tp: 13116.9424 - fp: 1560.3132 - tn: 17292.4570 - fn: 5709.6992 - accuracy: 0.8070 - precision: 0.8937 - recall: 0.6967 - auc: 0.8942
# Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.20.hdf5
# 1639/1639 [==============================] - 698s 426ms/step - loss: 0.3259 - tp: 13117.1914 - fp: 1560.3185 - tn: 17292.7012 - fn: 5709.7017 - accuracy: 0.8070 - precision: 0.8937 - recall: 0.6967 - auc: 0.8942 - val_loss: 0.6937 - val_tp: 13525.0000 - val_fp: 1569.0000 - val_tn: 17741.7891 - val_fn: 5765.7109 - val_accuracy: 0.8100 - val_precision: 0.8961 - val_recall: 0.7011 - val_auc: 0.8972
#
# Epoch 00021: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.21.hdf5
# Epoch 22/50
# 1639/1639 [==============================] - 701s 428ms/step - loss: 0.3163 - tp: 13930.9014 - fp: 1577.7621 - tn: 18192.5645 - fn: 5821.6396 - accuracy: 0.8128 - precision: 0.8982 - recall: 0.7052 - auc: 0.9000 - val_loss: 0.6926 - val_tp: 14331.0000 - val_fp: 1589.0000 - val_tn: 18641.5586 - val_fn: 5882.9414 - val_accuracy: 0.8153 - val_precision: 0.9002 - val_recall: 0.7090 - val_auc: 0.9026
#
# Epoch 00022: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.22.hdf5
# Epoch 23/50
# 1639/1639 [==============================] - 701s 428ms/step - loss: 0.3163 - tp: 13930.9014 - fp: 1577.7621 - tn: 18192.5645 - fn: 5821.6396 - accuracy: 0.8128 - precision: 0.8982 - recall: 0.7052 - auc: 0.9000 - val_loss: 0.6926 - val_tp: 14331.0000 - val_fp: 1589.0000 - val_tn: 18641.5586 - val_fn: 5882.9414 - val_accuracy: 0.8153 - val_precision: 0.9002 - val_recall: 0.7090 - val_auc: 0.9026
# 1639/1639 [==============================] - 702s 429ms/step - loss: 0.3078 - tp: 14739.8691 - fp: 1598.5393 - tn: 19094.7715 - fn: 5932.6641 - accuracy: 0.8179 - precision: 0.9021 - recall: 0.7130 - auc: 0.9052 - val_loss: 0.6925 - val_tp: 15146.0000 - val_fp: 1605.0000 - val_tn: 19551.1172 - val_fn: 5985.3823 - val_accuracy: 0.8205 - val_precision: 0.9042 - val_recall: 0.7168 - val_auc: 0.9077
#
# Epoch 00023: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.23.hdf5
# Epoch 24/50
# 1639/1639 [==============================] - 699s 427ms/step - loss: 0.3006 - tp: 15546.1670 - fp: 1615.2184 - tn: 20007.4844 - fn: 6039.9780 - accuracy: 0.8228 - precision: 0.9059 - recall: 0.7202 - auc: 0.9100 - val_loss: 0.6937 - val_tp: 15956.0000 - val_fp: 1619.0000 - val_tn: 20456.8086 - val_fn: 6098.6914 - val_accuracy: 0.8251 - val_precision: 0.9079 - val_recall: 0.7235 - val_auc: 0.9123
#
# Epoch 00024: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.24.hdf5
# Epoch 25/50
# 1639/1639 [==============================] - 700s 427ms/step - loss: 0.2921 - tp: 16368.8857 - fp: 1624.5369 - tn: 20907.4316 - fn: 6151.0205 - accuracy: 0.8274 - precision: 0.9097 - recall: 0.7268 - auc: 0.9145 - val_loss: 0.6937 - val_tp: 16768.0000 - val_fp: 1627.0000 - val_tn: 21372.9160 - val_fn: 6205.5835 - val_accuracy: 0.8296 - val_precision: 0.9116 - val_recall: 0.7299 - val_auc: 0.9166
#
# Epoch 00025: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/ACL/sagittal/weights.25.hdf5
# Epoch 26/50
#  377/1639 [=====>........................] - ETA: 8:32 - loss: 0.2868 - tp: 16863.4961 - fp: 1627.0000 - tn: 21515.8418 - fn: 6257.6631 - accuracy: 0.8296 - precision: 0.9120 - recall: 0.7294 - auc: 0.9168Buffered data was truncated after reaching the output size limit.

# %%
label_type = 'ACL'
exam_view = 'sagittal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
print(total)
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
print(total)
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/ACL/sagittal/weights.14.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=20, initial_epoch = 14,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21691809
# =================================================================
# Total params: 21,691,809
# Trainable params: 21,657,377
# Non-trainable params: 34,432
# _________________________________________________________________
# 1017
# 113
# Initializing Data Generator:
# factor :  4.16243654822335
# model:  inception
# data type:  train
# Combination:  ACL  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1639
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  9.272727272727273
# model:  inception
# data type:  test
# Combination:  ACL  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  204
# input size:  (299, 299)
# Epoch 15/20
# 1638/1639 [============================>.] - ETA: 1s - loss: 0.0043 - tp: 419.9298 - fp: 0.9103 - tn: 397.0000 - fn: 1.6600 - accuracy: 0.9963 - precision: 0.9942 - recall: 0.9928 - auc: 0.9969Epoch 15/20
# 1639/1639 [==============================] - 2765s 2s/step - loss: 0.0043 - tp: 420.1721 - fp: 0.9103 - tn: 397.2575 - fn: 1.6602 - accuracy: 0.9963 - precision: 0.9942 - recall: 0.9928 - auc: 0.9969 - val_loss: 0.6845 - val_tp: 817.0000 - val_fp: 1.0000 - val_tn: 869.2892 - val_fn: 54.2108 - val_accuracy: 0.9689 - val_precision: 0.9988 - val_recall: 0.9390 - val_auc: 0.9976
#
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/ACL/sagittal/weights.15.hdf5
# Epoch 16/20
# 1639/1639 [==============================] - 2551s 2s/step - loss: 0.0011 - tp: 1229.1696 - fp: 1.0000 - tn: 1328.8304 - fn: 104.0000 - accuracy: 0.9593 - precision: 0.9992 - recall: 0.9195 - auc: 0.9966 - val_loss: 0.7021 - val_tp: 1636.0000 - val_fp: 1.0000 - val_tn: 1790.1177 - val_fn: 157.3824 - val_accuracy: 0.9559 - val_precision: 0.9994 - val_recall: 0.9125 - val_auc: 0.9961
#
# Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/ACL/sagittal/weights.16.hdf5
# Epoch 17/20
# 1639/1639 [==============================] - 2533s 2s/step - loss: 7.3076e-04 - tp: 2047.2703 - fp: 1.0000 - tn: 2251.7297 - fn: 206.0000 - accuracy: 0.9535 - precision: 0.9995 - recall: 0.9075 - auc: 0.9956 - val_loss: 0.6841 - val_tp: 2455.0000 - val_fp: 1.0000 - val_tn: 2718.7549 - val_fn: 252.7451 - val_accuracy: 0.9533 - val_precision: 0.9996 - val_recall: 0.9068 - val_auc: 0.9954
#
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/ACL/sagittal/weights.17.hdf5
# Epoch 18/20
# 1639/1639 [==============================] - 2532s 2s/step - loss: 5.3744e-04 - tp: 2863.6475 - fp: 1.0000 - tn: 3176.3525 - fn: 308.0000 - accuracy: 0.9511 - precision: 0.9996 - recall: 0.9023 - auc: 0.9952 - val_loss: 0.6840 - val_tp: 3274.0000 - val_fp: 1.0000 - val_tn: 3633.3872 - val_fn: 362.1127 - val_accuracy: 0.9501 - val_precision: 0.9997 - val_recall: 0.9005 - val_auc: 0.9951
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/ACL/sagittal/weights.18.hdf5
# Epoch 19/20
# 1639/1639 [==============================] - 2545s 2s/step - loss: 4.5123e-04 - tp: 3682.2710 - fp: 1.0000 - tn: 4098.7290 - fn: 410.0000 - accuracy: 0.9497 - precision: 0.9997 - recall: 0.8995 - auc: 0.9949 - val_loss: 0.7025 - val_tp: 4093.0000 - val_fp: 1.0000 - val_tn: 4560.5737 - val_fn: 458.9265 - val_accuracy: 0.9496 - val_precision: 0.9998 - val_recall: 0.8992 - val_auc: 0.9948
#
# Epoch 00019: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/ACL/sagittal/weights.19.hdf5
# Epoch 20/20
# 1639/1639 [==============================] - 2550s 2s/step - loss: 3.6232e-04 - tp: 4505.1069 - fp: 1.0000 - tn: 5016.8931 - fn: 512.0000 - accuracy: 0.9488 - precision: 0.9998 - recall: 0.8977 - auc: 0.9947 - val_loss: 0.7027 - val_tp: 4912.0000 - val_fp: 1.0000 - val_tn: 5479.9707 - val_fn: 563.5294 - val_accuracy: 0.9485 - val_precision: 0.9998 - val_recall: 0.8971 - val_auc: 0.9947
#
# Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/ACL/sagittal/weights.20.hdf5

# %% [markdown]
# ## training on augmneted data

# %%
label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_inc_model(2,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=1)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=1)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/abnormal/axial/weights.20.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=30, initial_epoch = 20,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)

# %%
label_type = 'ACL'
exam_view = 'sagittal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/"+label_type+"/"+exam_view+"/weights.20.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])
neg = total - pos
class_count_valid = {0: neg, 1: pos}
batch_size = 1
print(model.metrics_names)
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , batch_size=1,model="inception",data_type='valid', shuffle=False,label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
model.evaluate_generator(valid_data_gen, total, verbose=1)
