# %%
import numpy as np
import tensorflow as tf
from __future__ import print_function
import tensorflow.keras
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import os
from google.colab import drive
drive.mount('/content/gdrive')

# Install a Drive FUSE wrapper.
 # https://github.com/astrada/google-drive-ocamlfuse
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null 
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

# Generate auth tokens for Colab

from google.colab import auth 
auth.authenticate_user()

# Generate creds for the Drive FUSE library.

from oauth2client.client import GoogleCredentials 
creds = GoogleCredentials.get_application_default()
import getpass 
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass() 
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# Create a directory and mount Google Drive using that directory.

# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# E: Package 'python-software-properties' has no installation candidate

# %%
import pandas as pd 
l=pd.read_csv("drive/Colab Notebooks/valid-acl.csv")
label=l['label']
index=l['index']
dataset=[]
x=[""]

for i in index:
  dataset.append(np.load('drive/Colab Notebooks/sagittal/'+str(i)+'.npy', encoding='bytes'))

# %%
 dataset=np.asarray(dataset)
print(dataset[0].shape)

# %%
min=100
for i in dataset:
  if min>i.shape[0]:
    min=i.shape[0]
print(min)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
import numpy as np
import keras
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import np_utils
from keras.utils import plot_model
import scipy.misc
from keras.initializers import glorot_uniform
from matplotlib.pyplot import imshow
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.initializers import RandomNormal as RN
from tensorflow.keras.initializers import GlorotNormal as GN
from tensorflow.keras.initializers import GlorotUniform as GU

K.set_image_data_format('channels_last')
K.set_learning_phase(1)
class ResNet50():

  def __init__(self,shape ,weightsPath = None):
    self.shape =shape;
    self.weightsPath = weightsPath;

  def identity_block(self,X,f , filters, stage, block):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, #heddin layers in prev, #W in prev, #channels in prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (#H, #W, #C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    
    # Second component of main path 
    X = Conv2D(filters = F2, kernel_size=(f,f), strides = (1,1), padding='same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(filters = F3, kernel_size=(1,1), strides = (1,1), padding="valid", name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X,X_shortcut])
    X = Activation('relu')(X)
    
    
    return X

  def convolutional_block(self,X, filters, stage, block, s =2):
    """
    Implementation of the convolutional block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    #F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(filters = filters[0], kernel_size= (1, 1), strides = (s,s),padding="valid", name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    

    # Second component of main path 
    X = Conv2D(filters = filters[1], kernel_size=(3,3), strides=(1,1), name = conv_name_base + '2b', padding="same",kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name= bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(filters = filters[2], kernel_size=(1,1), strides = (1,1), name= conv_name_base + '2c',padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    ##### SHORTCUT PATH #### 
    X_shortcut = Conv2D(filters = filters[2], kernel_size= (1,1), strides=(s,s), name=conv_name_base + '1', padding="valid", kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base+'1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)
    
    
    return X

  def getModel(self,classes = 1):
    """
    Arguments:
    classes -- integer, number of classes
    Returns:
    model -- a Model() instance in Keras
    """
    input = Input(shape=self.shape);
    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    st2filters=[64, 64, 256]
    X = self.convolutional_block(X,st2filters, 2, 'a', 1)
    X = self.identity_block(X, 3, [64, 64, 256], 2, 'b')
    X = self.identity_block(X, 3, [64, 64, 256], 2, 'c')


    # Stage 3
    X = self.convolutional_block(X, [128,128,512],3,'a', 2)
    X = self.identity_block(X, 3, [128,128,512], 3, 'b')
    X = self.identity_block(X, 3, [128,128,512], 3, 'c')
    X = self.identity_block(X, 3, [128,128,512], 3, 'd')

    # Stage 4 
    X = self.convolutional_block(X, [256,256,1024],4 , 'a', 2)
    X = self.identity_block(X, 3, [256, 256, 1024],4 , 'b')
    X = self.identity_block(X, 3, [256, 256, 1024],4 , 'c')
    X = self.identity_block(X, 3, [256, 256, 1024],4 , 'd')
    X = self.identity_block(X, 3, [256, 256, 1024],4 , 'e')
    X = self.identity_block(X, 3, [256, 256, 1024],4 , 'f')

    # Stage 5 
    X = self.convolutional_block(X, [256,256,2048], 5,'a', 3)
    X = self.identity_block(X, 3, [256,256,2048], 5, 'b')
    X = self.identity_block(X, 3, [256,256,2048], 5, 'c')

    # AVGPOOL (Ã¢â€°Ë†1 line). Use "X = AveragePooling2D(...)(X)"
    #X = AveragePooling2D((2,2), name='avg_pool')(X)
    

    # output layer
    #X = Flatten()(X)
    #X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = input, outputs = X, name='ResNet50')

    if self.weightsPath:
        model.load_weights(self.weightsPath)

    return model

class MRNet_ResNet_layer(keras.layers.Layer):
    
  def __init__(self, input_shape,batch_size):
    super(MRNet_ResNet_layer, self).__init__()
    self.ResNet = ResNet50(input_shape).getModel()
    self.avg_pooling = AveragePooling2D((2, 2), name='avg_pool')
    self.fc = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))
    self.b_size = batch_size

  def compute_output_shape(self, input_shape):
    return (None, 2)

  @tf.function
  def call(self, inputs):
    arr = []
    for index in range(self.b_size):
      out = self.ResNet(inputs[index])
      out = tf.squeeze(self.avg_pooling(out), axis=[1, 2])
      out = keras.backend.max(out, axis=0, keepdims=True)
      out = tf.squeeze(out)
      arr.append(out)
    output = tf.stack(arr, axis=0)
    output = self.fc(output)
    return output

  def compute_output_shape(self, input_shape):
    return (None, 1)


def scheduler(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * tf.math.exp(0.1 * (10 - epoch))

def MRNet_ResNet_model(batch_size, combination = ["abnormal", "axial"]):
  METRICS = [
    tf.keras.metrics.TruePositives(name='tp'),
    tf.keras.metrics.FalsePositives(name='fp'),
    tf.keras.metrics.TrueNegatives(name='tn'),
    tf.keras.metrics.FalseNegatives(name='fn'), 
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
  ]

  b_size = batch_size
  model = keras.Sequential()
  model.add(MRNet_ResNet_layer(( 256, 256, 3), b_size))
  model(Input(shape=(None, 224, 224, 3)))
  model.compile(
      #optimizer=tf.keras.optimizers.Adam(lr=0.001, decay=1e-2),
      optimizer=tf.keras.optimizers.RMSprop(lr=.0001),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=METRICS)
  data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
  checkpoint_dir = data_path+"training_ResNet/" + combination[0] + "/" + combination[1] + "/"
  # checkpoint_dir = os.path.dirname(checkpoint_path)
  if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
  os.chdir(checkpoint_dir)
  cp_callback = keras.callbacks.ModelCheckpoint(checkpoint_dir+"weights.{epoch:02d}.hdf5",
                                                 save_weights_only=True,
                                                 verbose=1)
  tcb = TestCallback(model)
  return model, [cp_callback, tcb]

class TestCallback(tf.keras.callbacks.Callback):
  def __init__(self, model):
    super(TestCallback, self).__init__()
    self.model = model

  def on_epoch_end(self, epoch, logs=None):
    if(epoch == 0):
      self.w = self.model.layers[0].get_weights()[0]
      return
    self.w_after = self.model.layers[0].get_weights()[0]
    print('  TestCallback: ', (self.w == self.w_after).all())
    self.w = self.w_after

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator4 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc
# Out:
# Using TensorFlow backend.

# %%
label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(1,0.000001,[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

#model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.03.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
# print(class_count_train, class_count_test)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="ResNet",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(224,224),  aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(len(train_data_gen))
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=14, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  ResNet
# data type:  train
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (224, 224)
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  ResNet
# data type:  test
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (224, 224)
# Epoch 1/14
# 1646/1646 [==============================] - 505s 307ms/step - loss: 0.7254 - tp: 412.2801 - fp: 304.9739 - tn: 105.6555 - fn: 0.5905 - accuracy: 0.5783 - precision: 0.5431 - recall: 0.9989 - auc: 0.6947 - val_loss: 2.2959 - val_tp: 866.9333 - val_fp: 494.1333 - val_tn: 373.0000 - val_fn: 2.4333 - val_accuracy: 0.7143 - val_precision: 0.6372 - val_recall: 0.9972 - val_auc: 0.7742
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.01.hdf5
# Epoch 2/14
# 1646/1646 [==============================] - 476s 289ms/step - loss: 0.2080 - tp: 1325.8688 - fp: 552.7880 - tn: 766.1379 - fn: 4.7053 - accuracy: 0.7827 - precision: 0.7008 - recall: 0.9965 - auc: 0.8238 - val_loss: 2.0764 - val_tp: 1774.4778 - val_fp: 599.8722 - val_tn: 1180.0000 - val_fn: 8.1500 - val_accuracy: 0.8294 - val_precision: 0.7475 - val_recall: 0.9954 - val_auc: 0.8587
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.02.hdf5
#   TestCallback:  False
# Epoch 3/14
# 1646/1646 [==============================] - 473s 287ms/step - loss: 0.1305 - tp: 2233.2498 - fp: 646.8372 - tn: 1586.4131 - fn: 9.0000 - accuracy: 0.8518 - precision: 0.7739 - recall: 0.9959 - auc: 0.8811 - val_loss: 1.4980 - val_tp: 2685.3389 - val_fp: 692.0389 - val_tn: 2002.0000 - val_fn: 9.1222 - val_accuracy: 0.8699 - val_precision: 0.7952 - val_recall: 0.9966 - val_auc: 0.8993
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.03.hdf5
# 1646/1646 [==============================] - 476s 289ms/step - loss: 0.2080 - tp: 1325.8688 - fp: 552.7880 - tn: 766.1379 - fn: 4.7053 - accuracy: 0.7827 - precision: 0.7008 - recall: 0.9965 - auc: 0.8238 - val_loss: 2.0764 - val_tp: 1774.4778 - val_fp: 599.8722 - val_tn: 1180.0000 - val_fn: 8.1500 - val_accuracy: 0.8294 - val_precision: 0.7475 - val_recall: 0.9954 - val_auc: 0.8587
#   TestCallback:  False
# Epoch 4/14
# 1646/1646 [==============================] - 472s 287ms/step - loss: 0.0980 - tp: 3141.2576 - fp: 737.0000 - tn: 2413.2424 - fn: 10.0000 - accuracy: 0.8808 - precision: 0.8093 - recall: 0.9968 - auc: 0.9121 - val_loss: 1.5258 - val_tp: 3600.2834 - val_fp: 779.2167 - val_tn: 2825.0000 - val_fn: 10.0000 - val_accuracy: 0.8906 - val_precision: 0.8221 - val_recall: 0.9972 - val_auc: 0.9221
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.04.hdf5
#   TestCallback:  False
# Epoch 5/14
# 1646/1646 [==============================] - 473s 288ms/step - loss: 0.0782 - tp: 4055.7764 - fp: 827.0000 - tn: 3234.7236 - fn: 10.0000 - accuracy: 0.8967 - precision: 0.8302 - recall: 0.9975 - auc: 0.9300 - val_loss: 0.1011 - val_tp: 4510.6221 - val_fp: 871.8778 - val_tn: 3648.0000 - val_fn: 10.0000 - val_accuracy: 0.9025 - val_precision: 0.8380 - val_recall: 0.9978 - val_auc: 0.9363
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.05.hdf5
#   TestCallback:  False
# Epoch 6/14
# 1646/1646 [==============================] - 471s 286ms/step - loss: 0.0644 - tp: 4976.4780 - fp: 917.0000 - tn: 4050.0220 - fn: 10.0000 - accuracy: 0.9067 - precision: 0.8442 - recall: 0.9980 - auc: 0.9417 - val_loss: 2.2559 - val_tp: 5423.2612 - val_fp: 962.2389 - val_tn: 4471.0000 - val_fn: 10.0000 - val_accuracy: 0.9105 - val_precision: 0.8493 - val_recall: 0.9982 - val_auc: 0.9466
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.06.hdf5
#   TestCallback:  False
# Epoch 7/14
# 1646/1646 [==============================] - 470s 286ms/step - loss: 0.0552 - tp: 5876.3740 - fp: 1007.0000 - tn: 4886.1260 - fn: 10.0000 - accuracy: 0.9135 - precision: 0.8535 - recall: 0.9983 - auc: 0.9503 - val_loss: 0.1173 - val_tp: 6335.3110 - val_fp: 1053.1888 - val_tn: 5294.0000 - val_fn: 10.0000 - val_accuracy: 0.9162 - val_precision: 0.8575 - val_recall: 0.9984 - val_auc: 0.9536
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.07.hdf5
# 1646/1646 [==============================] - 471s 286ms/step - loss: 0.0644 - tp: 4976.4780 - fp: 917.0000 - tn: 4050.0220 - fn: 10.0000 - accuracy: 0.9067 - precision: 0.8442 - recall: 0.9980 - auc: 0.9417 - val_loss: 2.2559 - val_tp: 5423.2612 - val_fp: 962.2389 - val_tn: 4471.0000 - val_fn: 10.0000 - val_accuracy: 0.9105 - val_precision: 0.8493 - val_recall: 0.9982 - val_auc: 0.9466
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.06.hdf5
#   TestCallback:  False
# Epoch 8/14
# 1646/1646 [==============================] - 470s 285ms/step - loss: 0.0479 - tp: 6793.2769 - fp: 1097.0000 - tn: 5705.2231 - fn: 10.0000 - accuracy: 0.9185 - precision: 0.8608 - recall: 0.9985 - auc: 0.9565 - val_loss: 2.1872 - val_tp: 7245.0444 - val_fp: 1146.4556 - val_tn: 6117.0000 - val_fn: 10.0000 - val_accuracy: 0.9204 - val_precision: 0.8634 - val_recall: 0.9986 - val_auc: 0.9590
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.08.hdf5
#   TestCallback:  False
# Epoch 9/14
# 1646/1646 [==============================] - 470s 285ms/step - loss: 0.0426 - tp: 7705.4946 - fp: 1187.0000 - tn: 6529.0054 - fn: 10.0000 - accuracy: 0.9224 - precision: 0.8664 - recall: 0.9987 - auc: 0.9613 - val_loss: 1.9280 - val_tp: 8164.4946 - val_fp: 1230.0056 - val_tn: 6940.0000 - val_fn: 10.0000 - val_accuracy: 0.9241 - val_precision: 0.8691 - val_recall: 0.9988 - val_auc: 0.9632
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.09.hdf5
#   TestCallback:  False
# Epoch 10/14
# 1646/1646 [==============================] - 471s 286ms/step - loss: 0.0384 - tp: 8627.9062 - fp: 1277.0000 - tn: 7342.5942 - fn: 10.0000 - accuracy: 0.9254 - precision: 0.8710 - recall: 0.9989 - auc: 0.9649 - val_loss: 0.1273 - val_tp: 9077.0449 - val_fp: 1320.4556 - val_tn: 7763.0000 - val_fn: 10.0000 - val_accuracy: 0.9268 - val_precision: 0.8730 - val_recall: 0.9989 - val_auc: 0.9664
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.10.hdf5
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.09.hdf5
#   TestCallback:  False
# Epoch 11/14
# 1646/1646 [==============================] - 474s 288ms/step - loss: 0.0348 - tp: 9533.9561 - fp: 1367.0000 - tn: 8172.5444 - fn: 10.0000 - accuracy: 0.9278 - precision: 0.8745 - recall: 0.9990 - auc: 0.9677 - val_loss: 0.0892 - val_tp: 9988.5615 - val_fp: 1411.9388 - val_tn: 8586.0000 - val_fn: 10.0000 - val_accuracy: 0.9289 - val_precision: 0.8762 - val_recall: 0.9990 - val_auc: 0.9689
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.11.hdf5
#   TestCallback:  False
# Epoch 12/14
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.0322 - tp: 10442.2520 - fp: 1457.0000 - tn: 8999.7432 - fn: 10.0000 - accuracy: 0.9298 - precision: 0.8775 - recall: 0.9990 - auc: 0.9699
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.11.hdf5
# 1646/1646 [==============================] - 473s 287ms/step - loss: 0.0322 - tp: 10442.5029 - fp: 1457.0000 - tn: 8999.9922 - fn: 10.0000 - accuracy: 0.9298 - precision: 0.8775 - recall: 0.9990 - auc: 0.9699 - val_loss: 0.1025 - val_tp: 10897.2051 - val_fp: 1506.2944 - val_tn: 9409.0000 - val_fn: 10.0000 - val_accuracy: 0.9305 - val_precision: 0.8786 - val_recall: 0.9991 - val_auc: 0.9710
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.12.hdf5
#   TestCallback:  False
# Epoch 13/14
# 1646/1646 [==============================] - 470s 285ms/step - loss: 0.0297 - tp: 11349.9004 - fp: 1547.0000 - tn: 9828.5830 - fn: 10.0000 - accuracy: 0.9315 - precision: 0.8800 - recall: 0.9991 - auc: 0.9720 - val_loss: 0.0663 - val_tp: 11815.0781 - val_fp: 1591.4222 - val_tn: 10232.0000 - val_fn: 10.0000 - val_accuracy: 0.9323 - val_precision: 0.8813 - val_recall: 0.9992 - val_auc: 0.9729
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.13.hdf5
#   TestCallback:  False
# Epoch 14/14
# 1646/1646 [==============================] - 472s 287ms/step - loss: 0.0278 - tp: 12271.1230 - fp: 1637.0000 - tn: 10643.3242 - fn: 10.0000 - accuracy: 0.9329 - precision: 0.8823 - recall: 0.9992 - auc: 0.9737 - val_loss: 0.0820 - val_tp: 12728.4727 - val_fp: 1681.0278 - val_tn: 11055.0000 - val_fn: 10.0000 - val_accuracy: 0.9336 - val_precision: 0.8833 - val_recall: 0.9992 - val_auc: 0.9744
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.14.hdf5
#   TestCallback:  False

# %%
##########################################################carful training validation
label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(1, 0.000001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.014.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , shuffle=1, batch_size=1,model="ResNet",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(valid_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(train_data_gen)):
  x, y = next(train_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(train_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  ResNet
# data type:  train
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (224, 224)
# tp =  823  fp =  0  tn =  823  fn =  0  accuracy =  1.0  auc =  1.0

# %%
label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(2,0.000001,[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.014.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
# print(class_count_train, class_count_test)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="ResNet",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(224,224),  aug_size=1)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=1)
# print(len(train_data_gen))
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=14, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  ResNet
# data type:  train
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (224, 224)
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  ResNet
# data type:  test
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (224, 224)
# Epoch 1/14
# 1645/1646 [============================>.] - ETA: 1s - loss: 0.4518 - tp: 746.4669 - fp: 330.6596 - tn: 489.3672 - fn: 79.5064 - accuracy: 0.7542 - precision: 0.6938 - recall: 0.9173 - auc: 0.8719Epoch 1/14
# 1646/1646 [==============================] - 3433s 2s/step - loss: 0.4518 - tp: 746.9089 - fp: 330.8512 - tn: 489.6774 - fn: 79.5626 - accuracy: 0.7542 - precision: 0.6938 - recall: 0.9173 - auc: 0.8719 - val_loss: 1.0650 - val_tp: 1556.2056 - val_fp: 724.1055 - val_tn: 1008.2167 - val_fn: 184.4722 - val_accuracy: 0.7386 - val_precision: 0.6827 - val_recall: 0.8940 - val_auc: 0.8586
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.01.hdf5
# Epoch 2/14
# 1646/1646 [==============================] - 3363s 2s/step - loss: 0.4328 - tp: 2341.5188 - fp: 1134.3263 - tn: 1526.5437 - fn: 296.6112 - accuracy: 0.7295 - precision: 0.6731 - recall: 0.8879 - auc: 0.8539 - val_loss: 1.2759 - val_tp: 3164.0000 - val_fp: 1530.2167 - val_tn: 2027.3722 - val_fn: 403.4111 - val_accuracy: 0.7287 - val_precision: 0.6741 - val_recall: 0.8869 - val_auc: 0.8518
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.02.hdf5
#   TestCallback:  False
# Epoch 3/14
#  943/1646 [================>.............] - ETA: 22:48 - loss: 0.4134 - tp: 3672.8208 - fp: 1795.3627 - tn: 2317.8313 - fn: 461.9852 - accuracy: 0.7262 - precision: 0.6716 - recall: 0.8882 - auc: 0.8494

# %%
label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(1, 0.000001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.01.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])
neg = total - pos
class_count_valid = {0: neg, 1: pos}
batch_size = 1
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , shuffle=1, batch_size=1,model="ResNet",data_type='valid', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(valid_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(valid_data_gen)):
  x, y = next(valid_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(valid_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  3.8
# model:  ResNet
# data type:  valid
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  120
# input size:  (224, 224)
# tp =  95  fp =  24  tn =  1  fn =  0  accuracy =  0.8  auc =  0.5242105263157895

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_ResNet_model(1,0.00001,[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

#model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.03.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
# print(class_count_train, class_count_test)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="ResNet",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(224,224),  aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(len(train_data_gen))
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=15, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  ResNet
# data type:  train
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (224, 224)
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  ResNet
# data type:  test
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (224, 224)
# Epoch 1/15
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.5240 - tp: 360.3246 - fp: 180.8334 - tn: 230.7921 - fn: 51.0498 - accuracy: 0.6668 - precision: 0.6283 - recall: 0.8876 - auc: 0.6875Epoch 1/15
# 1646/1646 [==============================] - 587s 356ms/step - loss: 0.5238 - tp: 360.5541 - fp: 180.8694 - tn: 231.0061 - fn: 51.0705 - accuracy: 0.6669 - precision: 0.6284 - recall: 0.8877 - auc: 0.6876 - val_loss: 0.3347 - val_tp: 782.6389 - val_fp: 281.9500 - val_tn: 585.5778 - val_fn: 86.3333 - val_accuracy: 0.7881 - val_precision: 0.7356 - val_recall: 0.9006 - val_auc: 0.8208
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.01.hdf5
# Epoch 2/15
# 1646/1646 [==============================] - 545s 331ms/step - loss: 0.1466 - tp: 1243.9800 - fp: 323.3621 - tn: 993.8427 - fn: 88.3153 - accuracy: 0.8394 - precision: 0.7887 - recall: 0.9315 - auc: 0.8868 - val_loss: 0.1462 - val_tp: 1694.3223 - val_fp: 362.2278 - val_tn: 1416.9500 - val_fn: 89.0000 - val_accuracy: 0.8734 - val_precision: 0.8240 - val_recall: 0.9501 - val_auc: 0.9259
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.02.hdf5
#   TestCallback:  False
# Epoch 3/15
# 1646/1646 [==============================] - 544s 330ms/step - loss: 0.0891 - tp: 2142.8049 - fp: 404.0000 - tn: 1839.6951 - fn: 89.0000 - accuracy: 0.8886 - precision: 0.8399 - recall: 0.9597 - auc: 0.9420 - val_loss: 1.6921 - val_tp: 2601.7944 - val_fp: 450.9222 - val_tn: 2246.7834 - val_fn: 89.0000 - val_accuracy: 0.8998 - val_precision: 0.8524 - val_recall: 0.9669 - val_auc: 0.9532
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.03.hdf5
#   TestCallback:  False
# Epoch 4/15
# 1646/1646 [==============================] - 540s 328ms/step - loss: 0.0650 - tp: 3061.6951 - fp: 491.0000 - tn: 2659.8049 - fn: 89.0000 - accuracy: 0.9074 - precision: 0.8612 - recall: 0.9716 - auc: 0.9600 - val_loss: 0.2162 - val_tp: 3518.0889 - val_fp: 534.9556 - val_tn: 3072.4556 - val_fn: 89.0000 - val_accuracy: 0.9135 - val_precision: 0.8681 - val_recall: 0.9753 - val_auc: 0.9654
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.04.hdf5
#   TestCallback:  False
# Epoch 5/15
# 1646/1646 [==============================] - 539s 328ms/step - loss: 0.0504 - tp: 3970.9519 - fp: 577.0000 - tn: 3490.5481 - fn: 89.0000 - accuracy: 0.9178 - precision: 0.8728 - recall: 0.9780 - auc: 0.9689 - val_loss: 0.1490 - val_tp: 4432.1890 - val_fp: 619.4833 - val_tn: 3899.8279 - val_fn: 89.0000 - val_accuracy: 0.9216 - val_precision: 0.8774 - val_recall: 0.9803 - val_auc: 0.9720
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.05.hdf5
#   TestCallback:  False
# Epoch 6/15
# 1646/1646 [==============================] - 538s 327ms/step - loss: 0.0408 - tp: 4892.3433 - fp: 664.0000 - tn: 4308.1567 - fn: 89.0000 - accuracy: 0.9242 - precision: 0.8803 - recall: 0.9821 - auc: 0.9741 - val_loss: 2.0047 - val_tp: 5344.6831 - val_fp: 707.7667 - val_tn: 4725.0498 - val_fn: 89.0000 - val_accuracy: 0.9267 - val_precision: 0.8831 - val_recall: 0.9836 - val_auc: 0.9760
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.06.hdf5
#   TestCallback:  False
# Epoch 7/15
# 1646/1646 [==============================] - 541s 328ms/step - loss: 0.0343 - tp: 5800.1694 - fp: 752.0000 - tn: 5138.3306 - fn: 89.0000 - accuracy: 0.9285 - precision: 0.8851 - recall: 0.9849 - auc: 0.9774 - val_loss: 1.3802 - val_tp: 6255.9775 - val_fp: 795.6389 - val_tn: 5551.8833 - val_fn: 89.0000 - val_accuracy: 0.9303 - val_precision: 0.8872 - val_recall: 0.9860 - val_auc: 0.9788
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.07.hdf5
#   TestCallback:  False
# Epoch 8/15
# 1646/1646 [==============================] - 542s 329ms/step - loss: 0.0295 - tp: 6712.2432 - fp: 837.0000 - tn: 5967.2568 - fn: 89.0000 - accuracy: 0.9319 - precision: 0.8890 - recall: 0.9869 - auc: 0.9799 - val_loss: 2.1096 - val_tp: 7173.0835 - val_fp: 878.2444 - val_tn: 6378.1724 - val_fn: 89.0000 - val_accuracy: 0.9334 - val_precision: 0.8909 - val_recall: 0.9877 - val_auc: 0.9810
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.08.hdf5
#   TestCallback:  False
# Epoch 9/15
# 1646/1646 [==============================] - 540s 328ms/step - loss: 0.0258 - tp: 7628.4346 - fp: 924.0000 - tn: 6790.0654 - fn: 89.0000 - accuracy: 0.9343 - precision: 0.8919 - recall: 0.9885 - auc: 0.9817 - val_loss: 2.3520 - val_tp: 8082.4775 - val_fp: 970.0222 - val_tn: 7203.0000 - val_fn: 89.0000 - val_accuracy: 0.9352 - val_precision: 0.8929 - val_recall: 0.9891 - val_auc: 0.9824
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.09.hdf5
#   TestCallback:  False
# Epoch 10/15
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.0230 - tp: 8536.5000 - fp: 1014.0000 - tn: 7617.5005 - fn: 89.0000 - accuracy: 0.9360 - precision: 0.8938 - recall: 0.9897 - auc: 0.9830
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.09.hdf5
# 1646/1646 [==============================] - 542s 329ms/step - loss: 0.0230 - tp: 8536.7520 - fp: 1014.0000 - tn: 7617.7485 - fn: 89.0000 - accuracy: 0.9360 - precision: 0.8938 - recall: 0.9897 - auc: 0.9830 - val_loss: 2.2614 - val_tp: 8995.6719 - val_fp: 1059.8278 - val_tn: 8026.0000 - val_fn: 89.0000 - val_accuracy: 0.9368 - val_precision: 0.8946 - val_recall: 0.9902 - val_auc: 0.9836
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.10.hdf5
#   TestCallback:  False
# Epoch 11/15
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.0207 - tp: 9462.5469 - fp: 1104.0000 - tn: 8427.4531 - fn: 89.0000 - accuracy: 0.9374 - precision: 0.8955 - recall: 0.9907 - auc: 0.9841
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.10.hdf5
# 1646/1646 [==============================] - 544s 330ms/step - loss: 0.0207 - tp: 9462.7900 - fp: 1104.0000 - tn: 8427.7100 - fn: 89.0000 - accuracy: 0.9374 - precision: 0.8955 - recall: 0.9907 - auc: 0.9841 - val_loss: 0.0803 - val_tp: 9906.4111 - val_fp: 1152.0889 - val_tn: 8849.0000 - val_fn: 89.0000 - val_accuracy: 0.9379 - val_precision: 0.8958 - val_recall: 0.9911 - val_auc: 0.9846
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.11.hdf5
#   TestCallback:  False
# Epoch 12/15
# 1646/1646 [==============================] - 541s 328ms/step - loss: 0.0189 - tp: 10359.8447 - fp: 1194.0000 - tn: 9266.6533 - fn: 89.0000 - accuracy: 0.9386 - precision: 0.8966 - recall: 0.9915 - auc: 0.9850 - val_loss: 2.2247 - val_tp: 10824.4336 - val_fp: 1237.0667 - val_tn: 9672.0000 - val_fn: 89.0000 - val_accuracy: 0.9392 - val_precision: 0.8974 - val_recall: 0.9918 - val_auc: 0.9855
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.12.hdf5
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.11.hdf5
#   TestCallback:  False
# Epoch 13/15
# 1646/1646 [==============================] - 548s 333ms/step - loss: 0.0174 - tp: 11279.7207 - fp: 1284.0000 - tn: 10082.7646 - fn: 89.0000 - accuracy: 0.9396 - precision: 0.8978 - recall: 0.9922 - auc: 0.9858 - val_loss: 0.1800 - val_tp: 11730.2334 - val_fp: 1334.2667 - val_tn: 10495.0000 - val_fn: 89.0000 - val_accuracy: 0.9398 - val_precision: 0.8979 - val_recall: 0.9925 - val_auc: 0.9861
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/axial/weights.13.hdf5
#   TestCallback:  False
# Epoch 14/15
#  779/1646 [=============>................] - ETA: 4:36 - loss: 0.0163 - tp: 11974.0195 - fp: 1374.0000 - tn: 10690.9805 - fn: 89.0000 - accuracy: 0.9394 - precision: 0.8971 - recall: 0.9926 - auc: 0.9859

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_ResNet_model(1, 0.000001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.02.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])
neg = total - pos
class_count_valid = {0: neg, 1: pos}
batch_size = 1
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , shuffle=1, batch_size=1,model="ResNet",data_type='valid', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(valid_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(valid_data_gen)):
  x, y = next(valid_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(valid_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  3.8
# model:  ResNet
# data type:  valid
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  120
# input size:  (224, 224)
# tp =  94  fp =  25  tn =  0  fn =  1  accuracy =  0.7833333333333333  auc =  0.48673684210526313

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(1,0.00001,[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

#model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.03.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
# print(class_count_train, class_count_test)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="ResNet",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(224,224),  aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(len(train_data_gen))
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=15, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  ResNet
# data type:  train
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (224, 224)
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  ResNet
# data type:  test
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (224, 224)
# Epoch 1/15
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.4737 - tp: 376.1653 - fp: 163.3489 - tn: 242.8960 - fn: 40.5897 - accuracy: 0.7044 - precision: 0.6628 - recall: 0.9060 - auc: 0.7169Epoch 1/15
# 1646/1646 [==============================] - 1250s 759ms/step - loss: 0.4735 - tp: 376.4016 - fp: 163.3821 - tn: 243.1160 - fn: 40.6002 - accuracy: 0.7044 - precision: 0.6629 - recall: 0.9060 - auc: 0.7170 - val_loss: 0.3247 - val_tp: 815.3834 - val_fp: 256.7833 - val_tn: 606.1389 - val_fn: 58.1944 - val_accuracy: 0.8189 - val_precision: 0.7610 - val_recall: 0.9333 - val_auc: 0.8409
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.01.hdf5
# Epoch 2/15
# 1646/1646 [==============================] - 1196s 726ms/step - loss: 0.1281 - tp: 1263.8190 - fp: 305.8117 - tn: 1019.8694 - fn: 60.0000 - accuracy: 0.8572 - precision: 0.8005 - recall: 0.9531 - auc: 0.8942 - val_loss: 0.1301 - val_tp: 1717.9333 - val_fp: 353.6555 - val_tn: 1430.0000 - val_fn: 60.9111 - val_accuracy: 0.8837 - val_precision: 0.8295 - val_recall: 0.9658 - val_auc: 0.9280
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.02.hdf5
#   TestCallback:  False
# Epoch 3/15
# 1646/1646 [==============================] - 1201s 729ms/step - loss: 0.0788 - tp: 2185.7935 - fp: 396.0000 - tn: 1832.7065 - fn: 61.0000 - accuracy: 0.8967 - precision: 0.8453 - recall: 0.9725 - auc: 0.9433 - val_loss: 0.1362 - val_tp: 2633.6611 - val_fp: 440.7444 - val_tn: 2253.0000 - val_fn: 61.0944 - val_accuracy: 0.9069 - val_precision: 0.8567 - val_recall: 0.9773 - val_auc: 0.9549
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.03.hdf5
#   TestCallback:  False
# Epoch 4/15
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.0587 - tp: 3085.0754 - fp: 486.0000 - tn: 2667.9246 - fn: 62.0000 - accuracy: 0.9125 - precision: 0.8633 - recall: 0.9802 - auc: 0.9609
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.03.hdf5
# 1646/1646 [==============================] - 1199s 729ms/step - loss: 0.0587 - tp: 3085.3274 - fp: 486.0000 - tn: 2668.1726 - fn: 62.0000 - accuracy: 0.9125 - precision: 0.8633 - recall: 0.9802 - auc: 0.9609 - val_loss: 2.0820 - val_tp: 3544.7388 - val_fp: 531.7611 - val_tn: 3076.0000 - val_fn: 62.0000 - val_accuracy: 0.9177 - val_precision: 0.8696 - val_recall: 0.9828 - val_auc: 0.9660
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.04.hdf5
#   TestCallback:  False
# Epoch 5/15
# 1646/1646 [==============================] - 1198s 728ms/step - loss: 0.0454 - tp: 4001.1846 - fp: 576.0000 - tn: 3488.3154 - fn: 62.0000 - accuracy: 0.9212 - precision: 0.8738 - recall: 0.9847 - auc: 0.9695 - val_loss: 0.1679 - val_tp: 4458.7778 - val_fp: 620.7222 - val_tn: 3899.0000 - val_fn: 62.0000 - val_accuracy: 0.9245 - val_precision: 0.8778 - val_recall: 0.9863 - val_auc: 0.9723
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.05.hdf5
#   TestCallback:  False
# Epoch 6/15
# 1646/1646 [==============================] - 1197s 727ms/step - loss: 0.0370 - tp: 4920.2720 - fp: 666.0000 - tn: 4305.2280 - fn: 62.0000 - accuracy: 0.9267 - precision: 0.8806 - recall: 0.9875 - auc: 0.9742 - val_loss: 1.8110 - val_tp: 5371.5942 - val_fp: 710.9056 - val_tn: 4722.0000 - val_fn: 62.0000 - val_accuracy: 0.9289 - val_precision: 0.8832 - val_recall: 0.9886 - val_auc: 0.9761
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/sagittal/weights.06.hdf5
#   TestCallback:  False
# Epoch 7/15
#  481/1646 [=======>......................] - ETA: 13:48 - loss: 0.0320 - tp: 5536.9375 - fp: 756.0000 - tn: 4842.0625 - fn: 62.0000 - accuracy: 0.9269 - precision: 0.8798 - recall: 0.9889 - auc: 0.9753

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(1, 0.000001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.06.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])
neg = total - pos
class_count_valid = {0: neg, 1: pos}
batch_size = 1
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , shuffle=1, batch_size=1,model="ResNet",data_type='valid', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(valid_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(valid_data_gen)):
  x, y = next(valid_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(valid_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  3.8
# model:  ResNet
# data type:  valid
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  120
# input size:  (224, 224)
# tp =  95  fp =  25  tn =  0  fn =  0  accuracy =  0.7916666666666666  auc =  0.5326315789473685

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'coronal'
model, cbs = MRNet_ResNet_model(1,0.00001,[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

#model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.03.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
# print(class_count_train, class_count_test)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="ResNet",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(224,224),  aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(len(train_data_gen))
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=10, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  4.242268041237113
# model:  ResNet
# data type:  train
# Combination:  abnormal  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1646
# input size:  (224, 224)
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  ResNet
# data type:  test
# Combination:  abnormal  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (224, 224)
# Epoch 1/10
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.4983 - tp: 352.1088 - fp: 144.1337 - tn: 264.3131 - fn: 62.4444 - accuracy: 0.7075 - precision: 0.6773 - recall: 0.8535 - auc: 0.7184Epoch 1/10
# Epoch 1/10
# 1646/1646 [==============================] - 539s 328ms/step - loss: 0.4981 - tp: 352.3366 - fp: 144.1653 - tn: 264.5334 - fn: 62.4648 - accuracy: 0.7076 - precision: 0.6773 - recall: 0.8535 - auc: 0.7185 - val_loss: 0.6487 - val_tp: 773.2278 - val_fp: 240.2722 - val_tn: 627.0000 - val_fn: 96.0000 - val_accuracy: 0.8066 - val_precision: 0.7636 - val_recall: 0.8895 - val_auc: 0.8370
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.01.hdf5
# Epoch 2/10
# 1646/1646 [==============================] - 476s 289ms/step - loss: 0.1527 - tp: 1224.8269 - fp: 290.2867 - tn: 1037.6713 - fn: 96.7151 - accuracy: 0.8490 - precision: 0.8037 - recall: 0.9244 - auc: 0.8928 - val_loss: 1.3799 - val_tp: 1685.4833 - val_fp: 335.0167 - val_tn: 1445.0000 - val_fn: 97.0000 - val_accuracy: 0.8788 - val_precision: 0.8344 - val_recall: 0.9456 - val_auc: 0.9269
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.02.hdf5
#   TestCallback:  False
# Epoch 3/10
# 1646/1646 [==============================] - 480s 292ms/step - loss: 0.0912 - tp: 2136.6289 - fp: 381.0000 - tn: 1860.8712 - fn: 97.0000 - accuracy: 0.8920 - precision: 0.8473 - recall: 0.9561 - auc: 0.9408 - val_loss: 0.2060 - val_tp: 2597.0945 - val_fp: 426.4055 - val_tn: 2268.0000 - val_fn: 97.0000 - val_accuracy: 0.9029 - val_precision: 0.8591 - val_recall: 0.9640 - val_auc: 0.9520
# 1646/1646 [==============================] - 476s 289ms/step - loss: 0.1527 - tp: 1224.8269 - fp: 290.2867 - tn: 1037.6713 - fn: 96.7151 - accuracy: 0.8490 - precision: 0.8037 - recall: 0.9244 - auc: 0.8928 - val_loss: 1.3799 - val_tp: 1685.4833 - val_fp: 335.0167 - val_tn: 1445.0000 - val_fn: 97.0000 - val_accuracy: 0.8788 - val_precision: 0.8344 - val_recall: 0.9456 - val_auc: 0.9269
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.03.hdf5
#   TestCallback:  False
# Epoch 4/10
# 1646/1646 [==============================] - 480s 291ms/step - loss: 0.0656 - tp: 3044.7405 - fp: 471.0000 - tn: 2688.7595 - fn: 97.0000 - accuracy: 0.9093 - precision: 0.8654 - recall: 0.9689 - auc: 0.9578 - val_loss: 2.0288 - val_tp: 3510.4277 - val_fp: 516.0722 - val_tn: 3091.0000 - val_fn: 97.0000 - val_accuracy: 0.9150 - val_precision: 0.8719 - val_recall: 0.9731 - val_auc: 0.9632
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.04.hdf5
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.03.hdf5
#   TestCallback:  False
# Epoch 5/10
# 1646/1646 [==============================] - 479s 291ms/step - loss: 0.0507 - tp: 3957.0000 - fp: 561.0000 - tn: 3512.5000 - fn: 97.0000 - accuracy: 0.9188 - precision: 0.8755 - recall: 0.9760 - auc: 0.9666 - val_loss: 0.1642 - val_tp: 4420.5391 - val_fp: 608.9611 - val_tn: 3914.0000 - val_fn: 97.0000 - val_accuracy: 0.9219 - val_precision: 0.8790 - val_recall: 0.9785 - val_auc: 0.9696
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.05.hdf5
#   TestCallback:  False
# Epoch 6/10
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.0407 - tp: 4870.9736 - fp: 651.0000 - tn: 4334.0264 - fn: 97.0000 - accuracy: 0.9247 - precision: 0.8819 - recall: 0.9804 - auc: 0.9721
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.05.hdf5
# 1646/1646 [==============================] - 479s 291ms/step - loss: 0.0407 - tp: 4871.2290 - fp: 651.0000 - tn: 4334.2710 - fn: 97.0000 - accuracy: 0.9247 - precision: 0.8819 - recall: 0.9804 - auc: 0.9721 - val_loss: 2.1073 - val_tp: 5336.3667 - val_fp: 696.1334 - val_tn: 4737.0000 - val_fn: 97.0000 - val_accuracy: 0.9270 - val_precision: 0.8846 - val_recall: 0.9821 - val_auc: 0.9738
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.06.hdf5
#   TestCallback:  False
# Epoch 7/10
# 1646/1646 [==============================] - 481s 292ms/step - loss: 0.0338 - tp: 5797.2905 - fp: 741.0000 - tn: 5144.2095 - fn: 97.0000 - accuracy: 0.9287 - precision: 0.8865 - recall: 0.9835 - auc: 0.9751 - val_loss: 0.1274 - val_tp: 6246.6333 - val_fp: 788.8666 - val_tn: 5560.0000 - val_fn: 97.0000 - val_accuracy: 0.9302 - val_precision: 0.8879 - val_recall: 0.9847 - val_auc: 0.9766
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.07.hdf5
#   TestCallback:  False
# Epoch 8/10
# 1645/1646 [============================>.] - ETA: 0s - loss: 0.0292 - tp: 6698.1060 - fp: 831.0000 - tn: 5978.8940 - fn: 97.0000 - accuracy: 0.9317 - precision: 0.8895 - recall: 0.9857 - auc: 0.9778
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.07.hdf5
# 1646/1646 [==============================] - 483s 293ms/step - loss: 0.0292 - tp: 6698.3604 - fp: 831.0000 - tn: 5979.1396 - fn: 97.0000 - accuracy: 0.9317 - precision: 0.8895 - recall: 0.9857 - auc: 0.9778 - val_loss: 0.1030 - val_tp: 7165.6055 - val_fp: 872.8945 - val_tn: 6383.0000 - val_fn: 97.0000 - val_accuracy: 0.9332 - val_precision: 0.8914 - val_recall: 0.9866 - val_auc: 0.9788
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.08.hdf5
#   TestCallback:  False
# Epoch 9/10
# 1646/1646 [==============================] - 483s 293ms/step - loss: 0.0292 - tp: 6698.3604 - fp: 831.0000 - tn: 5979.1396 - fn: 97.0000 - accuracy: 0.9317 - precision: 0.8895 - recall: 0.9857 - auc: 0.9778 - val_loss: 0.1030 - val_tp: 7165.6055 - val_fp: 872.8945 - val_tn: 6383.0000 - val_fn: 97.0000 - val_accuracy: 0.9332 - val_precision: 0.8914 - val_recall: 0.9866 - val_auc: 0.9788
# 1646/1646 [==============================] - 481s 292ms/step - loss: 0.0254 - tp: 7605.8105 - fp: 921.0000 - tn: 6807.6895 - fn: 97.0000 - accuracy: 0.9340 - precision: 0.8919 - recall: 0.9874 - auc: 0.9794 - val_loss: 0.0903 - val_tp: 8074.3169 - val_fp: 967.1833 - val_tn: 7206.0000 - val_fn: 97.0000 - val_accuracy: 0.9349 - val_precision: 0.8930 - val_recall: 0.9881 - val_auc: 0.9801
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.09.hdf5
#   TestCallback:  False
# Epoch 10/10
# 1646/1646 [==============================] - 482s 293ms/step - loss: 0.0225 - tp: 8526.7578 - fp: 1011.0000 - tn: 7622.7417 - fn: 97.0000 - accuracy: 0.9357 - precision: 0.8939 - recall: 0.9887 - auc: 0.9808 - val_loss: 0.0525 - val_tp: 8988.2773 - val_fp: 1056.2222 - val_tn: 8029.0000 - val_fn: 97.0000 - val_accuracy: 0.9365 - val_precision: 0.8949 - val_recall: 0.9893 - val_auc: 0.9814
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/abnormal/coronal/weights.10.hdf5
#   TestCallback:  False

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'coronal'
model, cbs = MRNet_ResNet_model(1, 0.00001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.10.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])
neg = total - pos
class_count_valid = {0: neg, 1: pos}
batch_size = 1
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , shuffle=1, batch_size=1,model="ResNet",data_type='valid', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(valid_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(valid_data_gen)):
  x, y = next(valid_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(valid_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  3.8
# model:  ResNet
# data type:  valid
# Combination:  abnormal  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  120
# input size:  (224, 224)
# tp =  95  fp =  25  tn =  0  fn =  0  accuracy =  0.7916666666666666  auc =  0.5814736842105264

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'coronal'
model, cbs = MRNet_ResNet_model(1, 0.00001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.10.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
batch_size = 1
test_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_test , shuffle=1, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(test_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(test_data_gen)):
  x, y = next(test_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(test_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  ResNet
# data type:  test
# Combination:  abnormal  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (224, 224)
# tp =  90  fp =  90  tn =  0  fn =  0  accuracy =  0.5  auc =  0.6090123456790124

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(1, 0.00001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.06.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
batch_size = 1
test_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_test , shuffle=1, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(test_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(test_data_gen)):
  x, y = next(test_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(test_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  ResNet
# data type:  test
# Combination:  abnormal  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (224, 224)
# tp =  90  fp =  90  tn =  0  fn =  0  accuracy =  0.5  auc =  0.6674074074074074

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_ResNet_model(1, 0.00001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.13.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
batch_size = 1
test_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_test , shuffle=1, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(test_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(test_data_gen)):
  x, y = next(test_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(test_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  3.9130434782608696
# model:  ResNet
# data type:  test
# Combination:  abnormal  and  axial
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  180
# input size:  (224, 224)
# tp =  90  fp =  90  tn =  0  fn =  0  accuracy =  0.5  auc =  0.6669135802469136

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'meniscus'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(1,0.00001,[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.05.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}
# print(class_count_train, class_count_test)
batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="ResNet",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(224,224),  aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="ResNet",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(len(train_data_gen))
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=10, verbose=True, callbacks=cbs,shuffle=True, use_multiprocessing=True, workers=6)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  1.778688524590164
# model:  ResNet
# data type:  train
# Combination:  meniscus  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1302
# input size:  (224, 224)
# Initializing Data Generator:
# factor :  2.6451612903225805
# model:  ResNet
# data type:  test
# Combination:  meniscus  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  163
# input size:  (224, 224)
# Epoch 1/10
# 1301/1302 [============================>.] - ETA: 1s - loss: 0.3459 - tp: 300.4028 - fp: 22.8885 - tn: 303.6064 - fn: 24.1022 - accuracy: 0.9265 - precision: 0.9298 - recall: 0.9205 - auc: 0.9794Epoch 1/10
# 1302/1302 [==============================] - 1449s 1s/step - loss: 0.3460 - tp: 300.6421 - fp: 22.8979 - tn: 303.8464 - fn: 24.1137 - accuracy: 0.9265 - precision: 0.9298 - recall: 0.9205 - auc: 0.9794 - val_loss: 0.7274 - val_tp: 626.7546 - val_fp: 47.4356 - val_tn: 642.2332 - val_fn: 67.5767 - val_accuracy: 0.9174 - val_precision: 0.9298 - val_recall: 0.9034 - val_auc: 0.9731
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/meniscus/sagittal/weights.01.hdf5
# Epoch 2/10
# 1302/1302 [==============================] - 1367s 1s/step - loss: 0.1223 - tp: 959.5937 - fp: 56.0000 - tn: 1003.9063 - fn: 97.0000 - accuracy: 0.9253 - precision: 0.9428 - recall: 0.9050 - auc: 0.9776 - val_loss: 0.5289 - val_tp: 1304.6442 - val_fp: 62.9877 - val_tn: 1358.0797 - val_fn: 123.2883 - val_accuracy: 0.9347 - val_precision: 0.9540 - val_recall: 0.9138 - val_auc: 0.9816
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/meniscus/sagittal/weights.02.hdf5
#   TestCallback:  False
# Epoch 3/10
# 1302/1302 [==============================] - 1356s 1s/step - loss: 0.0707 - tp: 1652.4731 - fp: 73.0000 - tn: 1713.0269 - fn: 143.0000 - accuracy: 0.9390 - precision: 0.9572 - recall: 0.9195 - auc: 0.9840 - val_loss: 0.8758 - val_tp: 1985.3068 - val_fp: 80.6626 - val_tn: 2076.8467 - val_fn: 171.1841 - val_accuracy: 0.9417 - val_precision: 0.9610 - val_recall: 0.9207 - val_auc: 0.9858
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/meniscus/sagittal/weights.03.hdf5
#   TestCallback:  False
# Epoch 4/10
# 1302/1302 [==============================] - 1365s 1s/step - loss: 0.0488 - tp: 2325.2373 - fp: 89.0000 - tn: 2437.2627 - fn: 195.0000 - accuracy: 0.9434 - precision: 0.9629 - recall: 0.9222 - auc: 0.9871 - val_loss: 0.8070 - val_tp: 2671.3496 - val_fp: 99.4724 - val_tn: 2791.2332 - val_fn: 216.9448 - val_accuracy: 0.9453 - val_precision: 0.9641 - val_recall: 0.9249 - val_auc: 0.9883
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/meniscus/sagittal/weights.04.hdf5
#   TestCallback:  False
# Epoch 5/10
# 1302/1302 [==============================] - 1367s 1s/step - loss: 0.0362 - tp: 3012.4932 - fp: 109.0000 - tn: 3150.0068 - fn: 240.0000 - accuracy: 0.9462 - precision: 0.9650 - recall: 0.9260 - auc: 0.9888 - val_loss: 0.7700 - val_tp: 3351.2271 - val_fp: 116.7853 - val_tn: 3511.4294 - val_fn: 264.5583 - val_accuracy: 0.9474 - val_precision: 0.9663 - val_recall: 0.9269 - val_auc: 0.9895
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/meniscus/sagittal/weights.05.hdf5
#   TestCallback:  False
# Epoch 6/10
#  232/1302 [====>.........................] - ETA: 17:58 - loss: 0.0288 - tp: 3420.6121 - fp: 127.0000 - tn: 3597.8879 - fn: 296.0000 - accuracy: 0.9432 - precision: 0.9642 - recall: 0.9204 - auc: 0.9884

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"

import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
import tensorflow as tf
from numpy.random import seed
from sklearn.utils import class_weight
from ResNet_model_generator2 import MRNet_ResNet_model
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc as roc_auc

label_type = 'meniscus'
exam_view = 'sagittal'
model, cbs = MRNet_ResNet_model(1, 0.00001,combination=[label_type, exam_view])
# print(model(tf.ones((12, 24, 224, 224, 3))).shape)

model.load_weights("/content/gdrive/My Drive/Colab Notebooks/MRNet/training_ResNet/"+label_type+"/"+exam_view+"/weights.05.hdf5")
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['valid'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['valid'][exam_view])
neg = total - pos
class_count_valid = {0: neg, 1: pos}
batch_size = 1
valid_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_valid , shuffle=1, batch_size=1,model="ResNet",data_type='valid', label_type=label_type, exam_type=exam_view, scale_to=(224,224), aug_size=0)
# print(model.predict(valid_data_gen, batch_size=None,verbose=1))
# print(model.metrics_names)
tp = 0
tn = 0
fp = 0
fn = 0
y_true = []
y_score = []
for i in range(len(valid_data_gen)):
  x, y = next(valid_data_gen)
  _y = model.predict_classes(x, batch_size=1, verbose=0)
  _y_score = model.predict_proba(x, batch_size=2)
  y_score.append(_y_score[0][0])
  y_true.append(y[0])
  if _y[0][0] == 1:
    if _y[0][0] == y[0]:
      tp += 1
    else:
      fp += 1
  else:
    if _y[0][0] == y[0]:
      tn += 1
    else:
      fn += 1
y_score = np.array(y_score)
y_true = np.array(y_true)
fpr, tpr, _ = roc_curve(y_true, y_score)
auc = roc_auc(fpr, tpr)
print ("tp = ", tp, " fp = ", fp, " tn = ", tn, " fn = ", fn, " accuracy = ", (tp+tn)/(len(valid_data_gen)), " auc = ", auc)

# model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=12, verbose=True, callbacks=cbs,shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Initializing Data Generator:
# factor :  1.3076923076923077
# model:  ResNet
# data type:  valid
# Combination:  meniscus  and  sagittal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/valid
# Number of inputs:  120
# input size:  (224, 224)
# tp =  25  fp =  17  tn =  51  fn =  27  accuracy =  0.6333333333333333  auc =  0.609445701357466
