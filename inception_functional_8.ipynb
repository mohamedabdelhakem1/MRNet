# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/Colab Notebooks/MRNet/"
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/MRNet

# %%
import os
import numpy as np
import glob
import csv
import keras
import scipy
from partition import partition
from data_generator import MRNet_data_generator
from keras.layers import Conv2D,Input, MaxPool2D, AveragePooling2D, Dropout, Dense, Flatten
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from matplotlib.pyplot import imshow
import random
from numpy.random import seed
from sklearn.utils import class_weight

from inception_model_generator_BN import MRNet_inc_model

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #trainning on augmented balanced data with only the skewed class augmented
# 20 epochs

# %%
label_type = 'meniscus'
exam_view = 'coronal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
print(total)
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
print(total)
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.50.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=100, initial_epoch = 50,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)
# Out:
# Tensor("sequential_1/mr_net_inception_layer_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Tensor("sequential_1/mr_net_inception_layer_1_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21691809
# =================================================================
# Total params: 21,691,809
# Trainable params: 21,622,945
# Non-trainable params: 68,864
# _________________________________________________________________
# 1017
# 113
# Initializing Data Generator:
# factor :  1.778688524590164
# model:  inception
# data type:  train
# Combination:  meniscus  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/train
# Number of inputs:  1302
# input size:  (299, 299)
# Initializing Data Generator:
# factor :  2.6451612903225805
# model:  inception
# data type:  test
# Combination:  meniscus  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  163
# input size:  (299, 299)
# Epoch 51/100
# 1302/1302 [==============================] - 666s 512ms/step - loss: 0.7269 - tp: 135.4094 - fp: 133.3341 - tn: 193.5000 - fn: 189.2565 - accuracy: 0.4945 - precision: 0.5035 - recall: 0.4110 - auc: 0.4905 - val_loss: 0.6931 - val_tp: 294.0981 - val_fp: 283.9693 - val_tn: 411.0613 - val_fn: 394.8712 - val_accuracy: 0.5095 - val_precision: 0.5088 - val_recall: 0.4266 - val_auc: 0.5107
#
# Epoch 00051: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/coronal/weights.51.hdf5
# Epoch 52/100
# 1302/1302 [==============================] - 582s 447ms/step - loss: 0.6937 - tp: 487.6851 - fp: 427.2534 - tn: 629.9324 - fn: 571.6290 - accuracy: 0.5270 - precision: 0.5318 - recall: 0.4592 - auc: 0.5294 - val_loss: 0.6931 - val_tp: 675.4356 - val_fp: 580.3313 - val_tn: 845.4785 - val_fn: 747.7546 - val_accuracy: 0.5338 - val_precision: 0.5379 - val_recall: 0.4745 - val_auc: 0.5432
#
# Epoch 00052: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/coronal/weights.52.hdf5
# Epoch 53/100
# 1302/1302 [==============================] - 583s 448ms/step - loss: 0.6820 - tp: 867.6060 - fp: 726.8710 - tn: 1060.2081 - fn: 926.8149 - accuracy: 0.5380 - precision: 0.5439 - recall: 0.4833 - auc: 0.5503 - val_loss: 0.6932 - val_tp: 1072.5337 - val_fp: 877.2945 - val_tn: 1280.4724 - val_fn: 1083.6993 - val_accuracy: 0.5454 - val_precision: 0.5501 - val_recall: 0.4974 - val_auc: 0.5605
#
# Epoch 00053: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/coronal/weights.53.hdf5
# Epoch 54/100
# 1302/1302 [==============================] - 582s 447ms/step - loss: 0.6621 - tp: 1287.1213 - fp: 1028.4585 - tn: 1504.1752 - fn: 1226.7450 - accuracy: 0.5528 - precision: 0.5555 - recall: 0.5116 - auc: 0.5701 - val_loss: 0.6932 - val_tp: 1523.3068 - val_fp: 1175.2516 - val_tn: 1713.8650 - val_fn: 1366.5767 - val_accuracy: 0.5602 - val_precision: 0.5645 - val_recall: 0.5271 - val_auc: 0.5805
#
# Epoch 00054: saving model to /content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/coronal/weights.54.hdf5
# Epoch 55/100
#  611/1302 [=============>................] - ETA: 4:47 - loss: 0.6560 - tp: 1641.6907 - fp: 1260.6007 - tn: 1822.0409 - fn: 1441.6677 - accuracy: 0.5617 - precision: 0.5656 - recall: 0.5324 - auc: 0.5836

# %% [markdown]
# trying learning rate = 0.00001

# %%
label_type = 'meniscus'
exam_view = 'coronal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
print(total)
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
print(total)
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

# model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/meniscus/coronal/weights.20.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=50, initial_epoch = 0,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)

# %% [markdown]
# ## training on augmneted data

# %%
label_type = 'abnormal'
exam_view = 'axial'
model, cbs = MRNet_inc_model(2,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)

pos = 0
for e in p['train'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['train'][exam_view])
neg = total - pos
class_count_train = {0: neg, 1: pos}
pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
neg = total - pos
class_count_test = {0: neg, 1: pos}

batch_size = 1
train_data_gen = MRNet_data_generator(data_path, p, l,class_count=class_count_train , batch_size=1,model="inception",data_type='train', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=1)
test_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_test, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=1)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/meniscus/coronal/weights.20.hdf5')
model.fit(x=train_data_gen,validation_data=test_data_gen, epochs=30, initial_epoch = 20,verbose=True, callbacks=[cbs],shuffle=False, use_multiprocessing=True, workers=6)

# %% [markdown]
# # **testing on external validation**

# %%
label_type = 'meniscus'
exam_view = 'coronal'
model, cbs = MRNet_inc_model(1,combination=[label_type, exam_view])
data_path = "/content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0"
p, l = partition(data_path)


pos = 0
for e in p['test'][exam_view]:
  if l[e][label_type] == 1:
    pos += 1
total = len(p['test'][exam_view])
print(total)
neg = total - pos
class_count_valid = {0: neg, 1: pos}

batch_size = 1
valid_data_gen = MRNet_data_generator(data_path, p, l, class_count=class_count_valid, batch_size=1,model="inception",data_type='test', label_type=label_type, exam_type=exam_view, scale_to=(299,299), aug_size=0)

model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN_smalllr/meniscus/axial/weights.50.hdf5')
# model.load_weights('/content/gdrive/My Drive/Colab Notebooks/MRNet/training_inception_BN/meniscus/coronal/weights.12.hdf5')
metrics = model.evaluate_generator(generator=valid_data_gen,steps= total,verbose=1);
model.metrics_names
print(metrics)
# Out:
# Tensor("sequential_1/mr_net_inception_layer_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Tensor("sequential_1/mr_net_inception_layer_1_1/dropout_1/cond/Identity:0", shape=(1, 2048), dtype=float32)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mr_net_inception_layer_1 (MR (None, 1)                 21691809
# =================================================================
# Total params: 21,691,809
# Trainable params: 21,622,945
# Non-trainable params: 68,864
# _________________________________________________________________
# 113
# Initializing Data Generator:
# factor :  2.6451612903225805
# model:  inception
# data type:  test
# Combination:  meniscus  and  coronal
# data path:  /content/gdrive/My Drive/Colab Notebooks/MRNet/dataset/MRNet-v1.0/test
# Number of inputs:  163
# input size:  (299, 299)
# 113/113 [==============================] - 66s 585ms/step
# [0.6931867003440857, 15.849557876586914, 13.22123908996582, 16.238937377929688, 11.690265655517578, 0.533418595790863, 0.49493640661239624, 0.5580541491508484, 0.4955752193927765]
